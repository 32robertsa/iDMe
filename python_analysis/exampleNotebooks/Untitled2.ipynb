# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from coffea import util
from coffea.processor import accumulate
import os
import re
import pandas as pd
import hist
import matplotlib as mpl
import mplhep
import sys

sys.path.append("../analysisTools/")
import plotTools as ptools
import utils
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
file = "../coffea/signal_2022/signal_2022_Mchi_trial_with_hist_go.coffea"
sig_histo = util.load(file)[0]

# for i in sig_histo.keys():
#     print (i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 3
#       1 file = "../coffea/signal_2022/signal_2022_Mchi_trial_with_hist_go.coffea"
#       2 sig_histo = util.load(file)[0]
# ----> 3 file.names()
#       4 # for i in sig_histo.keys():
#       5 #     print (i)
#
# AttributeError: 'str' object has no attribute 'names'

# %%
fig, ax = plt.subplots(figsize=(7,7))

m1=10
delta = 0.1
ctau = 10


# Plot settings
plot_dict = {
    'variable': 'GenEle_pt',
    'cut': 'cut1',
    'year': 2022
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': True,
    'doYerr': False, 
    'xlabel': "GenEle_pt",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events/0.1cm',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/',
    'outName': f'signal_GenEle_pt.png'
}

ptools.plot_signal_1D(sig_histo, m1, delta, ctau, plot_dict, style_dict)


# signal points
# m1s = [10, 30,50]
# deltas = [0.1]
# ctaus = [10]

# # Plot for variables signal points
# for m1 in m1s:
#     for delta in deltas:
#         for ctau in ctaus:
#             ptools.plot_signal_1D(sig_histo, m1, delta, ctau, plot_dict, style_dict)
# Out:
# I am issuing the type: <class 'hist.hist.Hist'>
# Saved: ./plots//signal_GenEle_pt.png

# %%
denominator = np.histogram(Gen

# %%
fig, ax = plt.subplots(figsize=(7,7))

m1=10
delta = 0.1
ctau = 10

# Plot settings
plot_dict = {
    'variable': 'sel_e1_pt',
    'cut': 'cut1',
    'year': 2022
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': True,
    'doYerr': False, 
    'xlabel': "sel_e1_pt",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events/0.1cm',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/',
    'outName': f'signal_sel_e1_pt.png'
}

ptools.plot_signal_1D(sig_histo, m1, delta, ctau, plot_dict, style_dict)


# signal points
# m1s = [10, 30,50]
# deltas = [0.1]
# ctaus = [10]

# # Plot for variables signal points
# for m1 in m1s:
#     for delta in deltas:
#         for ctau in ctaus:
#             ptools.plot_signal_1D(sig_histo, m1, delta, ctau, plot_dict, style_dict)
# Out:
# I am issuing the type: <class 'hist.hist.Hist'>
# Saved: ./plots//signal_sel_e1_pt.png

# %%
fig, ax = plt.subplots(figsize=(7,7))

m1=10
delta = 0.1
ctau = 10

# Plot settings
plot_dict = {
    'variable': 'LptElectron_pt',
    'cut': 'cut1',
    'year': 2022
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': True,
    'doYerr': False, 
    'xlabel': "LptElectron_pt",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events/0.1cm',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/',
    'outName': f'signal_LptElectron_pt.png'
}

ptools.plot_signal_1D(sig_histo, m1, delta, ctau, plot_dict, style_dict)


# signal points
# m1s = [10, 30,50]
# deltas = [0.1]
# ctaus = [10]

# # Plot for variables signal points
# for m1 in m1s:
#     for delta in deltas:
#         for ctau in ctaus:
#             ptools.plot_signal_1D(sig_histo, m1, delta, ctau, plot_dict, style_dict)
# Out:
# I am issuing the type: <class 'hist.hist.Hist'>
# Saved: ./plots//signal_LptElectron_pt.png

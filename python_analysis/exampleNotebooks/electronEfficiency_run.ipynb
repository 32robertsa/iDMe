# %%
# %load_ext autoreload
# %autoreload 2
import uproot
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak
import sys
sys.path.append("../analysisTools/")
from analysisTools import loadSchema
from analysisTools import Analyzer
from analysisTools import iDMeProcessor
#from analysisTools import loadSchema
import analysisTools as tools
import analysisSubroutines as routines
import importlib
import coffea.util as util
import time
import json
import os

print("has singletons?", hasattr(ak, "singletons"))
print("awkward module path:", getattr(ak, "__file__", "<built-in>"))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# has singletons? True
# awkward module path: /uscms/home/reshmar/nobackup/miniforge3/envs/coffea/lib/python3.8/site-packages/awkward/__init__.py

# %%
sample_config = "../configs/sample_configs/signal_2022_Mchi_10_30_50_aEM.json"
#sample_config = "../configs/sample_configs/signal_2018_official_GEDidMVA90WP_aEM.json"

cuts_config = "/uscms/home/reshmar/nobackup/CMSSW_13_0_13/src/iDMe/python_analysis/thesis_plots/electron_xclean/cut_configs/cuts.py" 

histos_config = "/uscms/home/reshmar/nobackup/CMSSW_13_0_13/src/iDMe/python_analysis/thesis_plots/electron_xclean/histo_configs/vtxhisto.py"  
#python_analysis/thesis_plots/electron_xclean/histo_configs/histos_noXcleanVars.py

model_config = "../configs/models/BDT_NJetG0_allSigns_goodvtx_v11_max_depth_7_n_estimators_800_lr_0.005.json"

# %%
outdir = "../coffea/new_trial_2022/"
os.makedirs(outdir, exist_ok=True)

# %%
analyzer = Analyzer(sample_config, histos_config, cuts_config, model_config,max_files_per_samp=1) 

t1 = time.time()
out = analyzer.process(execr="iterative")
#out = analyzer.process(execr='futures')
t2 = time.time()

#print("Runtime: {:.2f} minutes".format((t2-t1)/60))
util.save(out,f"{outdir}/match_simplehisto.coffea")
# Out:
# Output()
# iterative:)
# /uscms/home/reshmar/nobackup/miniforge3/envs/coffea/lib/python3.8/site-packages/awkward/_connect/_numpy.py:195:
# RuntimeWarning: invalid value encountered in divide
#   result = getattr(ufunc, method)(
# ctau: [0.0172, 0.039, 0.137, 0.045, 0.8, 0.399, ... 0.0783, 0.011, 0.017, 1.61, 0.174]
# Mean of ctau: 0.44420188437005836
# ctau from gen matched part: [0.0172, 0.0181, 0.0455, 0.00905, 0.0476, ... 0.0076, 0.0296, 0.0156, 0.011, 0.017]
# mean_ctau_gen: 0.018544965075238787
# ctau not from gen matched part: [0.039, 0.137, 0.045, 0.8, 0.399, 1.88, ... 0.0146, 0.0434, 0.0783, 1.61, 0.174]
# mean_ctau_no_gen: 0.717955399302953
# ctau: [0.0172, 0.039, 0.137, 0.045, 0.8, 0.399, ... 0.0783, 0.011, 0.017, 1.61, 0.174]
# Mean of ctau: 0.444304480519604
# ctau from gen matched part: [0.0172, 0.0181, 0.0455, 0.00905, 0.0476, ... 0.0076, 0.0296, 0.0156, 0.011, 0.017]
# mean_ctau_gen: 0.01854743225235219
# ctau not from gen matched part: [0.039, 0.137, 0.045, 0.8, 0.399, 1.88, ... 0.0146, 0.0434, 0.0783, 1.61, 0.174]
# mean_ctau_no_gen: 0.7180919953208557
# ctau: [0.0172, 0.039, 0.137, 0.045, 0.8, 0.399, ... 0.0783, 0.011, 0.017, 1.61, 0.174]
# Mean of ctau: 0.444304480519604
# ctau from gen matched part: [0.0172, 0.0181, 0.0455, 0.00905, 0.0476, ... 0.0076, 0.0296, 0.0156, 0.011, 0.017]
# mean_ctau_gen: 0.01854743225235219
# ctau not from gen matched part: [0.039, 0.137, 0.045, 0.8, 0.399, 1.88, ... 0.0146, 0.0434, 0.0783, 1.61, 0.174]
# mean_ctau_no_gen: 0.7180919953208557
# ctau: [0.0172, 0.039, 0.137, 0.045, 0.8, 0.399, ... 0.0783, 0.011, 0.017, 1.61, 0.174]
# Mean of ctau: 0.41784175529515766
# ctau from gen matched part: [0.0172, 0.00905, 0.0893, 0.00478, 0.000286, ... 0.0076, 0.0296, 0.011, 0.017]
# mean_ctau_gen: 0.017399548557995824
# ctau not from gen matched part: [0.039, 0.137, 0.045, 0.8, 0.399, 1.88, ... 0.0146, 0.0434, 0.0783, 1.61, 0.174]
# mean_ctau_no_gen: 0.65454827620852
# ctau: [0.0172, 0.039, 0.137, 0.045, 0.8, 0.399, ... 0.0236, 0.0115, 0.0434, 0.0783, 0.011]
# Mean of ctau: 0.4214115735517165
# ctau from gen matched part: [0.0172, 0.00905, 0.00478, 0.00562, 0.00837, ... 0.00667, 0.0336, 0.0115, 0.011]
# mean_ctau_gen: 0.01618807535858733
# ctau not from gen matched part: [0.039, 0.137, 0.045, 0.8, 0.399, 1.88, ... 0.438, 0.0366, 0.0236, 0.0434, 0.0783]
# mean_ctau_no_gen: 0.6407036149515394
# /uscms/home/reshmar/nobackup/miniforge3/envs/coffea/lib/python3.8/site-packages/awkward/_connect/_numpy.py:195:
# RuntimeWarning: invalid value encountered in divide
#   result = getattr(ufunc, method)(
# ctau: [0.0289, 0.0598, 0.439, 0.0628, 0.0573, ... 0.0223, 0.00483, 0.00998, 0.00546]
# Mean of ctau: 0.48361406090071646
# ctau from gen matched part: [0.0289, 0.00564, 0.0191, 0.00485, 0.00753, ... 0.0223, 0.00483, 0.00998, 0.00546]
# mean_ctau_gen: 0.012475077854022146
# ctau not from gen matched part: [0.0598, 0.439, 0.0628, 0.0573, 0.0657, ... 0.0181, 0.373, 0.491, 0.311, 0.225]
# mean_ctau_no_gen: 0.7768437603786118
# ctau: [0.0289, 0.0598, 0.439, 0.0628, 0.0573, ... 0.0223, 0.00483, 0.00998, 0.00546]
# Mean of ctau: 0.4836531842423126
# ctau from gen matched part: [0.0289, 0.00564, 0.0191, 0.00485, 0.00753, ... 0.0223, 0.00483, 0.00998, 0.00546]
# mean_ctau_gen: 0.012476387642877515
# ctau not from gen matched part: [0.0598, 0.439, 0.0628, 0.0573, 0.0657, ... 0.0181, 0.373, 0.491, 0.311, 0.225]
# mean_ctau_no_gen: 0.7768437603786118
# ctau: [0.0289, 0.0598, 0.439, 0.0628, 0.0573, ... 0.0223, 0.00483, 0.00998, 0.00546]
# Mean of ctau: 0.4836531842423126
# ctau from gen matched part: [0.0289, 0.00564, 0.0191, 0.00485, 0.00753, ... 0.0223, 0.00483, 0.00998, 0.00546]
# mean_ctau_gen: 0.012476387642877515
# ctau not from gen matched part: [0.0598, 0.439, 0.0628, 0.0573, 0.0657, ... 0.0181, 0.373, 0.491, 0.311, 0.225]
# mean_ctau_no_gen: 0.7768437603786118
# ctau: [0.0657, 0.0871, 0.0191, 0.00485, 0.00236, ... 0.225, 0.00386, 0.00998, 0.00546]
# Mean of ctau: 0.4582435086813157
# ctau from gen matched part: [0.0191, 0.00485, 0.00491, 0.00411, 0.00693, ... 0.00267, 0.00386, 0.00998, 0.00546]
# mean_ctau_gen: 0.011252702258441433
# ctau not from gen matched part: [0.0657, 0.0871, 0.00236, 0.0278, 0.0278, ... 0.0545, 0.0534, 0.905, 0.519, 0.225]
# mean_ctau_no_gen: 0.7107573427864851
# ctau: [0.00491, 0.00411, 0.0116, 0.0876, 0.0102, ... 0.905, 0.00267, 0.519, 0.225, 0.00546]
# Mean of ctau: 0.38646625376002675
# ctau from gen matched part: [0.00491, 0.00411, 0.0234, 0.0183, 0.00551, ... 0.0218, 0.00255, 0.00267, 0.00546]
# mean_ctau_gen: 0.010321266873329061
# ctau not from gen matched part: [0.0116, 0.0876, 0.0102, 3.42, 3.06, 0.0457, ... 0.0765, 0.0699, 0.905, 0.519,
# 0.225]
# mean_ctau_no_gen: 0.5814874597163012
# /uscms/home/reshmar/nobackup/miniforge3/envs/coffea/lib/python3.8/site-packages/awkward/_connect/_numpy.py:195:
# RuntimeWarning: invalid value encountered in divide
#   result = getattr(ufunc, method)(
# ctau: [0.00168, 2.75, 0.0726, 0.0552, 0.000729, ... 0.00706, 0.0331, 0.128, 0.00415]
# Mean of ctau: 0.5346443919170777
# ctau from gen matched part: [0.00168, 0.000729, 0.0126, 0.00228, 0.0164, ... 0.00966, 0.00315, 0.00706, 0.00415]
# mean_ctau_gen: 0.006417275838571659
# ctau not from gen matched part: [2.75, 0.0726, 0.0552, 0.0594, 0.0416, ... 0.254, 0.0153, 0.0185, 0.0331, 0.128]
# mean_ctau_no_gen: 0.83305496233622
# ctau: [0.00168, 2.75, 0.0726, 0.0552, 0.000729, ... 0.00706, 0.0331, 0.128, 0.00415]
# Mean of ctau: 0.5348198423696363
# ctau from gen matched part: [0.00168, 0.000729, 0.0126, 0.00228, 0.0164, ... 0.00966, 0.00315, 0.00706, 0.00415]
# mean_ctau_gen: 0.006419562474852467
# ctau not from gen matched part: [2.75, 0.0726, 0.0552, 0.0594, 0.0416, ... 0.254, 0.0153, 0.0185, 0.0331, 0.128]
# mean_ctau_no_gen: 0.8331921506148461
# ctau: [0.00168, 2.75, 0.0726, 0.0552, 0.000729, ... 0.00706, 0.0331, 0.128, 0.00415]
# Mean of ctau: 0.5348198423696363
# ctau from gen matched part: [0.00168, 0.000729, 0.0126, 0.00228, 0.0164, ... 0.00966, 0.00315, 0.00706, 0.00415]
# mean_ctau_gen: 0.006419562474852467
# ctau not from gen matched part: [2.75, 0.0726, 0.0552, 0.0594, 0.0416, ... 0.254, 0.0153, 0.0185, 0.0331, 0.128]
# mean_ctau_no_gen: 0.8331921506148461
# ctau: [0.00168, 0.0552, 0.000729, 0.0594, 0.00269, ... 0.517, 0.571, 0.00315, 0.0331]
# Mean of ctau: 0.5014834289980001
# ctau from gen matched part: [0.00168, 0.000729, 0.00269, 0.000169, ... 0.00444, 0.00347, 0.00301, 0.00315]
# mean_ctau_gen: 0.004663466938590535
# ctau not from gen matched part: [0.0552, 0.0594, 0.0239, 0.0186, 2.5, 2.92, ... 0.205, 0.0345, 0.517, 0.571,
# 0.0331]
# mean_ctau_no_gen: 0.7782501379431289
# ctau: [0.0552, 0.000729, 0.0594, 0.00269, 0.000169, ... 0.72, 0.00444, 0.00347, 0.00315]
# Mean of ctau: 0.48851053608764594
# ctau from gen matched part: [0.000729, 0.00269, 0.000169, 0.000502, ... 0.00205, 0.00444, 0.00347, 0.00315]
# mean_ctau_gen: 0.004213633055382586
# ctau not from gen matched part: [0.0552, 0.0594, 0.0239, 0.0186, 0.0247, 0.144, ... 0.11, 0.0826, 2.77, 2.96, 0.72]
# mean_ctau_no_gen: 0.735419921875
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

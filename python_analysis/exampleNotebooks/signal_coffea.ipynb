# %%
# %load_ext autoreload
# %autoreload 2
import uproot
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak
import sys
sys.path.append("../analysisTools/")
from analysisTools import Analyzer
from analysisTools import iDMeProcessor
from analysisTools import loadSchema
import analysisTools as tools
import analysisSubroutines as routines
import importlib
import coffea.util as util
import time
import json
import os
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# **Run coffea on skimmed ntuples**

# %%
sample_config = "../configs/sample_configs/signal_2022_Mchi-10p5_dMchi-1p0_ctau-10_2022_MINIAOD_aEM.json"   

cuts_config = "../configs/cut_configs/unskimmed_SR_BDT.py" 

histos_config = "../configs/histo_configs/histos_SR.py"   

model_config = "../configs/models/BDT_NJetG0_allSigns_goodvtx_v11_max_depth_7_n_estimators_800_lr_0.005.json"

# %%
outdir = "../coffea/unskimmed/"
os.makedirs(outdir, exist_ok=True)

# %%
#sample_config = "../configs/sample_configs/skimmed_bkg/skimmed_bkg_2018_v7_miniAOD_noNJetCut.json"
analyzer = Analyzer(sample_config, histos_config, cuts_config) 

#analyzer = iDMeProcessor(sample_config,sample_config,sample_config, histos_config, cuts_config) 

t1 = time.time()
out = analyzer.process(execr="iterative")
#out = analyzer.process(execr='futures')
t2 = time.time()

#print("Runtime: {:.2f} minutes".format((t2-t1)/60))
util.save(out,f"{outdir}/WJets_2022.coffea")

#del out, analyzer
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 #sample_config = "../configs/sample_configs/skimmed_bkg/skimmed_bkg_2018_v7_miniAOD_noNJetCut.json"
# ----> 2 analyzer = Analyzer(sample_config, histos_config, cuts_config)
#       4 #analyzer = iDMeProcessor(sample_config,sample_config,sample_config, histos_config, cuts_config)
#       6 t1 = time.time()
#
# TypeError: __init__() missing 1 required positional argument: 'model_json'

# %%
print(out)

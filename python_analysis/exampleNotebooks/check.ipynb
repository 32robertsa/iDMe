# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from coffea import util
from coffea.processor import accumulate
import os
import re
import pandas as pd
import hist
import matplotlib as mpl
import mplhep
import sys

sys.path.append("../analysisTools/")
import plotTools as ptools
import utils
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#coffea output file
f_sig = "../coffea/new_trial_2022/match_simplehisto.coffea"
#Nested Dictionary:
sig_histo = util.load(f_sig) [0]
sig_histo.keys()
# Out:
# dict_keys(['vtx_e1vxy', 'vtx_e2vxy', 'vtx_e3vxy', 'gen_ele_pt', 'match_ele_pt', 'match_ele_gen_pt', 'cutDesc', 'cutflow', 'cutflow_cts', 'cutflow_nevts', 'cutflow_vtx_matched'])

# %%
fig, ax = plt.subplots(figsize=(7,7))
m1=10
delta = 0.1
ctau = 10

# Plot settings
plot_dict = {
    'variable': 'vtx_e1vxy',
    'cut': 'cut1',
    'year': 2022
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': "ctau (in cm) ",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/trial_2022',
    'outName': f'vtx_ctau.png'
}

ptools.plot_signal_1D(sig_histo, m1, delta, ctau, plot_dict, style_dict)
# Out:
# Saved: ./plots/trial_2022/vtx_ctau.png

# %%
fig, ax = plt.subplots(figsize=(7,7))
m1=10
delta = 0.1
ctau = 10

# Plot settings
plot_dict = {
    'variable': 'vtx_e2vxy',
    'cut': 'cut1',
    'year': 2022
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': "ctau (from gen-matched vertices)",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/trial_2022',
    'outName': f'vtx_ctau_fromgen.png'
}

ptools.plot_signal_1D(sig_histo, m1, delta, ctau, plot_dict, style_dict)
# Out:
# Saved: ./plots/trial_2022/vtx_ctau_fromgen.png

# %%
fig, ax = plt.subplots(figsize=(7,7))
m1=10
delta = 0.1
ctau = 10

# Plot settings
plot_dict = {
    'variable': 'vtx_e3vxy',
    'cut': 'cut1',
    'year': 2022
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': "ctau (from not-gen matched vertices)",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/trial_2022',
    'outName': f'ctau_fromnotgen.png'
}

ptools.plot_signal_1D(sig_histo, m1, delta, ctau, plot_dict, style_dict)
# Out:
# Saved: ./plots/trial_2022/ctau_fromnotgen.png

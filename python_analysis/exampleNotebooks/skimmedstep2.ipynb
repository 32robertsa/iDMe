# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from coffea import util
from coffea.processor import accumulate
import os
import re
import pandas as pd
import hist
import matplotlib as mpl
import mplhep
import sys

sys.path.append("../analysisTools/")
import plotTools as ptools
import utils
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#coffea output file
f_bkg = "../coffea/bkg_2022/bkg_WJets.coffea"

#Nested Dictionary:
bkg_histo = util.load(f_bkg) [0]

# %%
#Description of the cuts
cuts = list(bkg_histo["cutDesc"].keys())  #The cuts
print (cuts)
# Out:
# ['all', 'hasVtx', 'cut1', 'cut2', 'cut3', 'cut4', 'cut5', 'cut6', 'cut7', 'cut8', 'cut9', 'cut10']

# %%
fig, ax = plt.subplots(figsize=(7,7))

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_vxy100',
    'cut': 'cut1',
    'year': 2022
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': [0,20],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"Lxy (in cm)",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/skimmed',
    'outName': f'WJets_sel_vtx_vxy100.png'
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)


#plt.title('')
plt.legend()
plt.show()
# Out:
# /uscms/home/reshmar/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots/skimmed/WJets_sel_vtx_vxy100.png

# %%
fig, ax = plt.subplots(figsize=(7,7))

# Plot settings
plot_dict = {
    'variable': 'PFMET',
    'cut': 'cut3',
    'year': 2022
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': [0,400],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': r"$E_T$ miss",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/skimmed',
    'outName': f'WJets_pTmiss.png'
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)


#plt.title('')
plt.legend()
plt.show()
# Out:
# Saved: ./plots/skimmed/WJets_pTmiss.png

# %%
#Top left plot
fig, ax = plt.subplots(figsize=(7,7))

# Plot settings
plot_dict = {
    'variable': 'minJetMETdPhi',
    'cut': 'cut9',
    'year': 2022
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': r"minJetMETdPhi",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/skimmed',
    'outName': f'WJets_minJetMETdPhi.png'
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)


#plt.title('')
plt.legend()
plt.show()
# Out:
# Saved: ./plots/skimmed/WJets_minJetMETdPhi.png

# %%
fig, ax = plt.subplots(figsize=(7,7))

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_mass',
    'cut': 'cut2',
    'year': 2022
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim':[0,50] ,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': r"$M_{e+e-}$ (in GeV)",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/skimmed',
    'outName': f'WJets_M.png'
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)


#plt.title('')
plt.legend()
plt.show()
# Out:
# Saved: ./plots/skimmed/WJets_M.png

# %%
fig, ax = plt.subplots(figsize=(7,7))

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_mass_refit',
    'cut': 'cut2',
    'year': 2022
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim':[0,60] ,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': r"Refit $M_{e+e-}$ (in GeV)",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/skimmed',
    'outName': f'WJets_Refit_M.png'
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)


#plt.title('')
plt.legend()
plt.show()
# Out:
# Saved: ./plots/skimmed/WJets_Refit_M.png

# %%
fig, ax = plt.subplots(figsize=(7,7))

# Plot settings
plot_dict = {
    'variable': 'nJets',
    'cut': 'cut2',
    'year': 2022
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim':[0,10] ,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': "Number of jets",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/skimmed',
    'outName': f'WJets_nJets.png'
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)


#plt.title('')
plt.legend()
plt.show()
# Out:
# Saved: ./plots/skimmed/WJets_nJets.png

# %%
fig, ax = plt.subplots(figsize=(7,7))

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_mass_low',
    'cut': 'cut2',
    'year': 2022
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim':[0,1] ,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': "Invariant mass of di-electrons (in GeV)",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/skimmed',
    'outName': f'WJets_sel_vtx_mass_low.png'
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)


#plt.title('')
plt.legend()
plt.show()
# Out:
# Saved: ./plots/skimmed/WJets_sel_vtx_mass_low.png

# %%
fig, ax = plt.subplots(figsize=(7,7))

# Plot settings
plot_dict = {
    'variable': 'lead_jet_pt',
    'cut': 'cut1',
    'year': 2022
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim':[0,100] ,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': "lead_jet_pt",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/skimmed',
    'outName': f'lead_jet_pt.png'
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)


#plt.title('')
plt.legend()
plt.show()
# Out:
# Saved: ./plots/skimmed/lead_jet_pt.png

# %%
fig, ax = plt.subplots(figsize=(7,7))

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_LxyCosThetaColl',
    'cut': 'cut1',
    'year': 2022
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim':[0,3] ,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': "sel_vtx_LxyCosThetaColl",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/skimmed',
    'outName': f'sel_vtx_LxyCosThetaColl.png'
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)


#plt.title('')
plt.legend()
plt.show()
# Out:
# Saved: ./plots/skimmed/sel_vtx_LxyCosThetaColl.png

# %%
fig, ax = plt.subplots(figsize=(7,7))

# Plot settings
plot_dict = {
    'variable': 'jetMETdPhi',
    'cut': 'cut8',
    'year': 2022
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim':[0,3] ,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': "jetMETdPhi",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/skimmed',
    'outName': f'WJets_jetMETdPhi.png'
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)


#plt.title('')
plt.legend()
plt.show()
# Out:
# Saved: ./plots/skimmed/WJets_jetMETdPhi.png

# %%
#Extras:

#cuts applied
lead_jet_pt=t["PFJet_pt"].array()

lead_jet_eta=t["PFJet_eta"].array()
abs_lead_jet_eta= abs(lead_jet_eta)

lead_jet_cut= (lead_jet_pt > 80) & (abs_lead_jet_eta < 2.4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       1 #Extras:
#       2
#       3 #cuts applied
# ----> 4 lead_jet_pt=t["PFJet_pt"].array()
#       6 lead_jet_eta=t["PFJet_eta"].array()
#       7 abs_lead_jet_eta= abs(lead_jet_eta)
#
# NameError: name 't' is not defined

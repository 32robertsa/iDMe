# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from coffea import util
from coffea.processor import accumulate
import os
import re
import pandas as pd
import hist
import matplotlib as mpl
import mplhep
import sys

sys.path.append("../../analysisTools/")
import plotTools as ptools
import utils

# %% [markdown]
# See here: https://cms-analysis.docs.cern.ch/guidelines/plotting/colors/ for plot styling suggestions from PubComm

# %% [markdown]
# ## Import coffea files -- signal and background

# %%
prefix = './coffea/skimmed/'
suffix = 'VR_localHEMveto'

# %%
# Signal
#sig_histo = util.load(f'{prefix}/signal{suffix}.coffea')[0]

# %%
# Background
bkg_histo = util.load(f'{prefix}/bkg_{suffix}.coffea')[0]

# %%
# Data
data_histo = util.load(f'{prefix}/data_{suffix}.coffea')[0]

# %%
bkg_histo.keys()
# Out:
# dict_keys(['sel_e1_pt', 'sel_e1_eta', 'sel_e1_phi', 'sel_e1_dxy', 'sel_e1_dxySignif', 'sel_e1_vxy1', 'sel_e1_vz', 'sel_e2_pt', 'sel_e2_eta', 'sel_e2_phi', 'sel_e2_dxy', 'sel_e2_dxySignif', 'sel_e2_vxy1', 'sel_e2_vz', 'sel_vtx_dR', 'sel_vtx_mindxy', 'sel_vtx_vxy1', 'sel_vtx_vxy10', 'sel_vtx_vxy100', 'sel_vtx_leadpT', 'sel_vtx_METdPhi', 'sel_vtx_mindRj', 'sel_vtx_chi2', 'sel_vtx_mass', 'sel_vtx_mindPhiJ', 'sel_vtx_sign', 'sel_vtx_pt', 'sel_vtx_eta', 'sel_vtx_phi', 'sel_vtx_type', 'sel_vtx_minEleDrJ', 'sel_vtx_minEleDPhiJ', 'sel_vtx_mass_low', 'sel_vtx_mindxy_low', 'sel_vtx_sign_etaProd', 'sel_vtx_CosThetaColl', 'sel_vtx_LxyCosThetaColl', 'sel_vtx_LxyCosThetaCollZoom', 'sel_vtx_LxyCosThetaCollZoomZoom', 'sel_vtx_eleDphi', 'sel_vtx_maxMiniRelIso', 'sel_vtx_maxMiniRelIsoCorr', 'sel_vtx_mass_refit', 'sel_vtx_mass_low_refit', 'sel_vtx_pt_refit', 'sel_vtx_eta_refit', 'sel_vtx_phi_refit', 'sel_vtx_dR_refit', 'sel_vtx_mass_refit_vs_sel_vtx_mass', 'sel_vtx_mass_low_refit_vs_sel_vtx_mass_low', 'sel_vtx_pt_refit_vs_sel_vtx_pt', 'sel_vtx_eta_refit_vs_sel_vtx_eta', 'sel_vtx_phi_refit_vs_sel_vtx_phi', 'sel_vtx_dR_refit_vs_sel_vtx_dR', 'sel_vtx_mass_vs_vxy', 'sel_vtx_mass_refit_vs_vxy', 'sel_e1_phi_vs_METphi', 'sel_e1_phi_vs_sel_e1_eta', 'sel_e1_phi_vs_sel_e1_pt', 'sel_e2_phi_vs_METphi', 'sel_e2_phi_vs_sel_e2_eta', 'sel_e2_phi_vs_sel_e2_pt', 'sel_vtx_phi_vs_sel_vtx_eta', 'sel_vtx_phi_vs_sel_vtx_pt', 'sel_vtx_phi_vs_sel_vtx_dR', 'sel_vtx_phi_vs_sel_vtx_pt800', 'sel_vtx_phi_refit_zoom_vs_sel_vtx_phi_zoom', 'sel_e1_phi_zoom_vs_sel_e1_eta', 'sel_e2_phi_zoom_vs_sel_e2_eta', 'sel_vtx_phi_vs_METphi', 'sel_vtx_phi_vs_lead_jet_phi', 'sel_vtx_phi_refit_vs_METphi', 'sel_vtx_phi_refit_vs_lead_jet_phi', 'METphi_vs_lead_jet_phi', 'sel_vtx_phi_refit_over_phi', 'sel_vtx_vx_vs_vy', 'PVx_vs_PVy', 'PFMET', 'PFMET1000', 'PFMETphi', 'jetMETdPhi', 'minJetMETdPhi', 'nJets', 'lead_jet_pt', 'lead_jet_eta', 'lead_jet_phi', 'jetMETratio', 'lead_jet_phi_vs_lead_jet_eta', 'PVx', 'PVy', 'cutDesc', 'cutflow', 'cutflow_cts', 'cutflow_nevts', 'cutflow_vtx_matched'])

# %%
bkg_histo['cutflow']
# Out:
# {'bkg_2018_ZJets_ZJetsNuNu_HT800to1200': defaultdict(float,
#              {'all': 0.03267497118530549,
#               'hasVtx': 0.00025268631858578326,
#               'cut2': 0.00024188374362765498,
#               'cut3': 0.00023953535776719229,
#               'cut4': 0.000228732782809064,
#               'cut5': 0.00012023735605568868,
#               'cut6': 0.00012023735605568868,
#               'cut7': 0.00012023735605568868,
#               'cut8': 0.00011460122999057828,
#               'cut9': 4.414965417669819e-05,
#               'cut10': 1.690837819533122e-05}),
#  'bkg_2018_ZJets_ZJetsNuNu_HT400to600': defaultdict(float,
#              {'all': 0.016667532369591447,
#               'hasVtx': 0.0001522930451345199,
#               'cut2': 0.00014270216725067542,
#               'cut3': 0.00014174307946229097,
#               'cut4': 0.00013634190086454697,
#               'cut5': 8.086624405220447e-05,
#               'cut6': 7.798898068705111e-05,
#               'cut7': 7.798898068705111e-05,
#               'cut8': 7.723180611727393e-05,
#               'cut9': 4.638956197501617e-05,
#               'cut10': 1.5042534786240281e-05}),
#  'bkg_2018_ZJets_ZJetsNuNu_HT600to800': defaultdict(float,
#              {'all': 0.02423554004791247,
#               'hasVtx': 0.00021205097301484662,
#               'cut2': 0.0002002386097381885,
#               'cut3': 0.0001992859997965225,
#               'cut4': 0.00019166512026319468,
#               'cut5': 0.00010840701136158825,
#               'cut6': 0.00010669231346658949,
#               'cut7': 0.00010669231346658949,
#               'cut8': 0.00010364396165325836,
#               'cut9': 4.553475521163373e-05,
#               'cut10': 1.5241759066655641e-05}),
#  'bkg_2018_ZJets_ZJetsNuNu_HT2500toInf': defaultdict(float,
#              {'all': 0.06783882128370318,
#               'hasVtx': 0.0002684323550465283,
#               'cut2': 0.00026470412789310425,
#               'cut3': 0.00026097590073968026,
#               'cut4': 0.0002535194464328323,
#               'cut5': 4.4738725841088044e-05,
#               'cut6': 4.4738725841088044e-05,
#               'cut7': 4.4738725841088044e-05,
#               'cut8': 3.3554044380816036e-05,
#               'cut9': 7.456454306848008e-06,
#               'cut10': 3.728227153424004e-06}),
#  'bkg_2018_ZJets_ZJetsNuNu_HT1200to2500': defaultdict(float,
#              {'all': 0.04633280498827598,
#               'hasVtx': 0.00032748660579782286,
#               'cut2': 0.00031438714156590994,
#               'cut3': 0.00031438714156590994,
#               'cut4': 0.0002934279987948493,
#               'cut5': 9.693603531615557e-05,
#               'cut6': 9.693603531615557e-05,
#               'cut7': 9.693603531615557e-05,
#               'cut8': 8.907635677700782e-05,
#               'cut9': 2.3579035617443245e-05,
#               'cut10': 5.239785692765166e-06}),
#  'bkg_2018_ZJets_ZJetsNuNu_HT100to200': defaultdict(float,
#              {'all': 0.0003411010014328394,
#               'hasVtx': 6.593670797867482e-07,
#               'cut2': 6.593670797867482e-07,
#               'cut3': 6.593670797867482e-07,
#               'cut4': 6.246635492716562e-07,
#               'cut5': 3.123317746358281e-07,
#               'cut6': 2.776282441207361e-07,
#               'cut7': 2.4292471360564407e-07,
#               'cut8': 2.4292471360564407e-07,
#               'cut9': 2.0822118309055205e-07,
#               'cut10': 3.470353051509201e-08}),
#  'bkg_2018_ZGamma_ZGToNuNuG': defaultdict(float,
#              {'all': 0.0008214427604253603,
#               'hasVtx': 5.534707186834291e-06,
#               'cut2': 5.995932988468508e-06,
#               'cut3': 5.995932988468508e-06,
#               'cut4': 5.534707186834291e-06,
#               'cut5': 3.228579090954324e-06,
#               'cut6': 2.7673535934171456e-06,
#               'cut7': 2.7673535934171456e-06,
#               'cut8': 2.7673535934171456e-06,
#               'cut9': 2.3061280958799675e-06,
#               'cut10': 4.6122561157356754e-07}),
#  'bkg_2018_ZJets_ZJetsNuNu_HT200to400': defaultdict(float,
#              {'all': 0.00690469040169835,
#               'hasVtx': 3.65281019347674e-05,
#               'cut2': 3.419839146239355e-05,
#               'cut3': 3.397860745556583e-05,
#               'cut4': 3.261594661323395e-05,
#               'cut5': 1.9472863004936176e-05,
#               'cut6': 1.77145909503144e-05,
#               'cut7': 1.736293653939004e-05,
#               'cut8': 1.736293653939004e-05,
#               'cut9': 1.4066176436974211e-05,
#               'cut10': 4.923161752940974e-06}),
#  'bkg_2018_ZGamma_ZGToLLG': defaultdict(float,
#              {'all': 5.765328075624818e-05,
#               'hasVtx': 9.62670709046007e-07,
#               'cut2': 9.62670709046007e-07,
#               'cut3': 9.62670709046007e-07,
#               'cut4': 9.09188984515123e-07,
#               'cut5': 6.417805281156556e-07,
#               'cut6': 6.417805281156556e-07,
#               'cut7': 6.417805281156556e-07,
#               'cut8': 6.417805281156556e-07,
#               'cut9': 2.6740851874507465e-07,
#               'cut10': 5.348170374901493e-08}),
#  'bkg_2018_ZGamma_ZGToJJG': defaultdict(float,
#              {'all': 2.4751249866443875e-05,
#               'hasVtx': 0.0,
#               'cut2': 0.0,
#               'cut3': 0.0,
#               'cut4': 0.0,
#               'cut5': 0.0,
#               'cut6': 0.0,
#               'cut7': 0.0,
#               'cut8': 0.0,
#               'cut9': 0.0,
#               'cut10': 0.0}),
#  'bkg_2018_ZGamma_ZG2JTo2L2JG': defaultdict(float,
#              {'all': 0.001518359445889541,
#               'hasVtx': 4.436109934869841e-05,
#               'cut2': 4.234468574193939e-05,
#               'cut3': 4.234468574193939e-05,
#               'cut4': 4.032827213518037e-05,
#               'cut5': 2.419696328110822e-05,
#               'cut6': 1.8147722460831164e-05,
#               'cut7': 1.8147722460831164e-05,
#               'cut8': 1.8147722460831164e-05,
#               'cut9': 1.0082068033795092e-05,
#               'cut10': 2.0164136067590185e-06}),
#  'bkg_2018_WJets_WJetsLNu_HT70to100': defaultdict(float,
#              {'all': 3.1985921765603197e-06,
#               'hasVtx': 0.0,
#               'cut2': 0.0,
#               'cut3': 0.0,
#               'cut4': 0.0,
#               'cut5': 0.0,
#               'cut6': 0.0,
#               'cut7': 0.0,
#               'cut8': 0.0,
#               'cut9': 0.0,
#               'cut10': 0.0}),
#  'bkg_2018_WJets_WJetsLNu_HT600to800': defaultdict(float,
#              {'all': 0.021801415122756036,
#               'hasVtx': 0.0001492466735287316,
#               'cut2': 0.00013810499477571867,
#               'cut3': 0.00013745722275519467,
#               'cut4': 0.00012942484970069696,
#               'cut5': 6.788650775091612e-05,
#               'cut6': 6.64614093057633e-05,
#               'cut7': 6.63318549016585e-05,
#               'cut8': 6.516586526471527e-05,
#               'cut9': 2.876107771126599e-05,
#               'cut10': 1.0623461136593743e-05}),
#  'bkg_2018_WJets_WJetsLNu_HT800to1200': defaultdict(float,
#              {'all': 0.029080558710035755,
#               'hasVtx': 0.000192850251437583,
#               'cut2': 0.00017984757302269978,
#               'cut3': 0.00017793138883524334,
#               'cut4': 0.00016999291148720938,
#               'cut5': 7.815294078840303e-05,
#               'cut6': 7.76054595919869e-05,
#               'cut7': 7.76054595919869e-05,
#               'cut8': 7.418370211438607e-05,
#               'cut9': 3.1069557896615566e-05,
#               'cut10': 1.27289378166751e-05}),
#  'bkg_2018_WJets_WJetsLNu_HT200to400': defaultdict(float,
#              {'all': 0.004844737050042073,
#               'hasVtx': 2.133085102991102e-05,
#               'cut2': 2.0048574038673473e-05,
#               'cut3': 1.9909949499080227e-05,
#               'cut4': 1.8783625114885087e-05,
#               'cut5': 1.0847370223171647e-05,
#               'cut6': 1.010226332285794e-05,
#               'cut7': 1.0067607187959627e-05,
#               'cut8': 1.0032951053061315e-05,
#               'cut9': 7.139163789052265e-06,
#               'cut10': 2.3912733079835257e-06}),
#  'bkg_2018_WJets_WJetsLNu_HT400to600': defaultdict(float,
#              {'all': 0.014683457140386066,
#               'hasVtx': 0.0001033162302900841,
#               'cut2': 9.766073570811689e-05,
#               'cut3': 9.710898013914448e-05,
#               'cut4': 9.172936334166347e-05,
#               'cut5': 4.8830367854058444e-05,
#               'cut6': 4.717510114714121e-05,
#               'cut7': 4.7037162254898106e-05,
#               'cut8': 4.66233455781688e-05,
#               'cut9': 2.6898083987405076e-05,
#               'cut10': 8.552211319072382e-06}),
#  'bkg_2018_WJets_WJetsLNu_HT2500toInf': defaultdict(float,
#              {'all': 0.061276725170285956,
#               'hasVtx': 0.00023931565257850697,
#               'cut2': 0.00022787426679786124,
#               'cut3': 0.0002259673691677536,
#               'cut4': 0.00021690960542474237,
#               'cut5': 3.6707779379571785e-05,
#               'cut6': 3.6707779379571785e-05,
#               'cut7': 3.6707779379571785e-05,
#               'cut8': 3.1940535304302725e-05,
#               'cut9': 3.8137952602152505e-06,
#               'cut10': 2.3836220376345316e-06}),
#  'bkg_2018_WJets_WJetsLNu_HT100to200': defaultdict(float,
#              {'all': 0.00018441416818451846,
#               'hasVtx': 3.8803612453344234e-07,
#               'cut2': 3.686343183067702e-07,
#               'cut3': 3.686343183067702e-07,
#               'cut4': 3.686343183067702e-07,
#               'cut5': 1.7461625604004905e-07,
#               'cut6': 1.5521444981337693e-07,
#               'cut7': 1.358126435867048e-07,
#               'cut8': 1.358126435867048e-07,
#               'cut9': 1.358126435867048e-07,
#               'cut10': 0.0}),
#  'bkg_2018_WJets_WJetsLNu_HT1200to2500': defaultdict(float,
#              {'all': 0.04106568862417724,
#               'hasVtx': 0.00021630735269114425,
#               'cut2': 0.00020566169838608794,
#               'cut3': 0.00020411884993607978,
#               'cut4': 0.00019594175315103653,
#               'cut5': 6.896532571536482e-05,
#               'cut6': 6.896532571536482e-05,
#               'cut7': 6.896532571536482e-05,
#               'cut8': 6.418249552033953e-05,
#               'cut9': 1.8205611710096306e-05,
#               'cut10': 8.331381630044073e-06}),
#  'bkg_2018_TTbar_TTToSemiLeptonic': defaultdict(float,
#              {'all': 0.0007555026240477923,
#               'hasVtx': 1.130974328460559e-05,
#               'cut2': 1.0528089916191075e-05,
#               'cut3': 1.046699005530312e-05,
#               'cut4': 1.0039292765387616e-05,
#               'cut5': 3.6280508898024393e-06,
#               'cut6': 3.44053839177915e-06,
#               'cut7': 3.4068283407405597e-06,
#               'cut8': 3.381545639683474e-06,
#               'cut9': 2.1721954425581934e-06,
#               'cut10': 7.858670434052655e-07}),
#  'bkg_2018_TTbar_TTToHadronic': defaultdict(float,
#              {'all': 2.6632972046634034e-06,
#               'hasVtx': 2.9299198287852133e-08,
#               'cut2': 2.6369278515574763e-08,
#               'cut3': 2.6369278515574763e-08,
#               'cut4': 2.6369278515574763e-08,
#               'cut5': 5.859839544554742e-09,
#               'cut6': 5.859839544554742e-09,
#               'cut7': 5.859839544554742e-09,
#               'cut8': 5.859839544554742e-09,
#               'cut9': 0.0,
#               'cut10': 0.0}),
#  'bkg_2018_TTbar_TTTo2L2Nu': defaultdict(float,
#              {'all': 0.0010410063934171699,
#               'hasVtx': 1.1654963318362773e-05,
#               'cut2': 1.0639987067166356e-05,
#               'cut3': 1.0584750319904006e-05,
#               'cut4': 1.0087619038042452e-05,
#               'cut5': 3.210638809876164e-06,
#               'cut6': 2.7756488223097176e-06,
#               'cut7': 2.665175211847434e-06,
#               'cut8': 2.665175304597503e-06,
#               'cut9': 1.4706796016109337e-06,
#               'cut10': 5.730816934096964e-07}),
#  'bkg_2018_TTX_TTWJetsToQQ': defaultdict(float,
#              {'all': 0.0015311310106125632,
#               'hasVtx': 1.5085034508584989e-05,
#               'cut2': 1.5085034508584989e-05,
#               'cut3': 1.5085034508584989e-05,
#               'cut4': 1.3199405013393983e-05,
#               'cut5': -1.8856293135731236e-06,
#               'cut6': -1.8856293135731236e-06,
#               'cut7': -1.8856293135731236e-06,
#               'cut8': -1.8856293135731236e-06,
#               'cut9': -1.8856293135731236e-06,
#               'cut10': 0.0}),
#  'bkg_2018_TTX_TTZToQQ': defaultdict(float,
#              {'all': 0.0010883660350839853,
#               'hasVtx': 1.6135217212659315e-05,
#               'cut2': 1.5627821448742708e-05,
#               'cut3': 1.5323381882460874e-05,
#               'cut4': 1.5221903030810675e-05,
#               'cut5': 6.291719668457476e-06,
#               'cut6': 6.1902404403908724e-06,
#               'cut7': 6.291719668457476e-06,
#               'cut8': 6.1902404403908724e-06,
#               'cut9': 2.84142215002893e-06,
#               'cut10': 1.11627292029415e-06}),
#  'bkg_2018_TTX_TTGJets': defaultdict(float,
#              {'all': 0.0011195323494744439,
#               'hasVtx': 1.4910530661144709e-05,
#               'cut2': 1.6153076232151708e-05,
#               'cut3': 1.5531802906950233e-05,
#               'cut4': 1.4289259494735138e-05,
#               'cut5': 4.348904641242712e-06,
#               'cut6': 4.348904641242712e-06,
#               'cut7': 4.348904641242712e-06,
#               'cut8': 4.348904641242712e-06,
#               'cut9': -1.8638163326430886e-06,
#               'cut10': 1.242544221762059e-06}),
#  'bkg_2018_SingleTop_ST_tW_top': defaultdict(float,
#              {'all': 0.0005985704225198175,
#               'hasVtx': 5.782073712345178e-06,
#               'cut2': 5.279285475174335e-06,
#               'cut3': 5.279285475174335e-06,
#               'cut4': 4.7764953464497065e-06,
#               'cut5': 1.6340647263580306e-06,
#               'cut6': 1.6340647263580306e-06,
#               'cut7': 1.6340647263580306e-06,
#               'cut8': 1.6340647263580306e-06,
#               'cut9': 1.1312755434102945e-06,
#               'cut10': 6.284864195736143e-07}),
#  'bkg_2018_SingleTop_ST_tW_antitop': defaultdict(float,
#              {'all': 0.000605006850527272,
#               'hasVtx': 5.549338080629361e-06,
#               'cut2': 4.9040665601480995e-06,
#               'cut3': 4.9040665601480995e-06,
#               'cut4': 4.7750120622137496e-06,
#               'cut5': 1.8067611538487332e-06,
#               'cut6': 1.6777067770631943e-06,
#               'cut7': 1.6777067770631943e-06,
#               'cut8': 1.6777067770631943e-06,
#               'cut9': 6.452718233532888e-07,
#               'cut10': 1.290543616419375e-07}),
#  'bkg_2018_SingleTop_ST_t-channel_top': defaultdict(float,
#              {'all': 0.00012532514221726937,
#               'hasVtx': 7.849927736227122e-07,
#               'cut2': 7.281840842665334e-07,
#               'cut3': 7.178552487934107e-07,
#               'cut4': 6.971975359564968e-07,
#               'cut5': 2.5305691941619166e-07,
#               'cut6': 2.169059219515925e-07,
#               'cut7': 2.169059219515925e-07,
#               'cut8': 2.0657706553313557e-07,
#               'cut9': 9.295967111177736e-08,
#               'cut10': 2.582213122801687e-08}),
#  'bkg_2018_TTX_TTWJetsToLNu': defaultdict(float,
#              {'all': 0.0032454714644285986,
#               'hasVtx': 4.8047283962475634e-05,
#               'cut2': 4.611838066106715e-05,
#               'cut3': 4.541696127873679e-05,
#               'cut4': 4.261127942073489e-05,
#               'cut5': 1.2976273723493269e-05,
#               'cut6': 1.2099498413410205e-05,
#               'cut7': 1.1924143567827614e-05,
#               'cut8': 1.157343279449232e-05,
#               'cut9': 6.663490625159108e-06,
#               'cut10': 2.630325659706666e-06}),
#  'bkg_2018_SingleTop_ST_t-channel_antitop': defaultdict(float,
#              {'all': 9.049433692040522e-05,
#               'hasVtx': 5.976232364034896e-07,
#               'cut2': 5.874940197109034e-07,
#               'cut3': 5.672355863257312e-07,
#               'cut4': 5.267187881127732e-07,
#               'cut5': 2.127132934541096e-07,
#               'cut6': 1.8232569479439098e-07,
#               'cut7': 1.8232569479439098e-07,
#               'cut8': 1.8232569479439098e-07,
#               'cut9': 1.1142127221269439e-07,
#               'cut10': 3.038761794148348e-08}),
#  'bkg_2018_QCD_QCD_HT700to1000': defaultdict(float,
#              {'all': 4.449890843550253e-05,
#               'hasVtx': 2.8122790941250994e-07,
#               'cut2': 2.379620771952007e-07,
#               'cut3': 2.379620771952007e-07,
#               'cut4': 2.1632916108654607e-07,
#               'cut5': 1.0816458054327304e-07,
#               'cut6': 1.0816458054327304e-07,
#               'cut7': 1.0816458054327304e-07,
#               'cut8': 1.0816458054327304e-07,
#               'cut9': 0.0,
#               'cut10': 0.0}),
#  'bkg_2018_QCD_QCD_HT300to500': defaultdict(float,
#              {'all': 6.991381008014867e-08,
#               'hasVtx': 1.7478452520037166e-08,
#               'cut2': 0.0,
#               'cut3': 0.0,
#               'cut4': 0.0,
#               'cut5': 0.0,
#               'cut6': 0.0,
#               'cut7': 0.0,
#               'cut8': 0.0,
#               'cut9': 0.0,
#               'cut10': 0.0}),
#  'bkg_2018_QCD_QCD_HT500to700': defaultdict(float,
#              {'all': 5.015798867837801e-06,
#               'hasVtx': 4.9014321184082743e-08,
#               'cut2': 4.9014321184082743e-08,
#               'cut3': 4.9014321184082743e-08,
#               'cut4': 4.9014321184082743e-08,
#               'cut5': 0.0,
#               'cut6': 0.0,
#               'cut7': 0.0,
#               'cut8': 0.0,
#               'cut9': 0.0,
#               'cut10': 0.0}),
#  'bkg_2018_SingleTop_ST_s-channel': defaultdict(float,
#              {'all': 0.00018885223024491232,
#               'hasVtx': 1.5863270924153102e-06,
#               'cut2': 1.507010637943641e-06,
#               'cut3': 1.4276942944174203e-06,
#               'cut4': 1.4276942944174203e-06,
#               'cut5': 4.758981166300482e-07,
#               'cut6': 3.965817453674654e-07,
#               'cut7': 3.965817453674654e-07,
#               'cut8': 3.965817453674654e-07,
#               'cut9': 7.93163504603112e-08,
#               'cut10': 7.93163504603112e-08}),
#  'bkg_2018_QCD_QCD_HT1000to1500': defaultdict(float,
#              {'all': 0.00024706548822399095,
#               'hasVtx': 1.9754703216203968e-06,
#               'cut2': 1.9096213108997166e-06,
#               'cut3': 1.9096213108997166e-06,
#               'cut4': 1.8437723001790369e-06,
#               'cut5': 8.560371393688386e-07,
#               'cut6': 8.560371393688386e-07,
#               'cut7': 8.560371393688386e-07,
#               'cut8': 7.901881286481587e-07,
#               'cut9': 0.0,
#               'cut10': 0.0}),
#  'bkg_2018_Multiboson_ZZZ': defaultdict(float,
#              {'all': 0.004445123874511268,
#               'hasVtx': 4.0410215866495856e-05,
#               'cut2': 4.0410215866495856e-05,
#               'cut3': 4.0410215866495856e-05,
#               'cut4': 4.0410215866495856e-05,
#               'cut5': 2.245012104733037e-05,
#               'cut6': 2.245012104733037e-05,
#               'cut7': 2.245012104733037e-05,
#               'cut8': 2.245012104733037e-05,
#               'cut9': 1.3470071619048816e-05,
#               'cut10': 8.980048418932147e-06}),
#  'bkg_2018_QCD_QCD_HT2000toInf': defaultdict(float,
#              {'all': 0.0026893563918693538,
#               'hasVtx': 9.79464795042457e-06,
#               'cut2': 9.79464795042457e-06,
#               'cut3': 9.613265580972264e-06,
#               'cut4': 9.250500842067651e-06,
#               'cut5': 1.451058955618455e-06,
#               'cut6': 1.451058955618455e-06,
#               'cut7': 1.451058955618455e-06,
#               'cut8': 1.2696765861661481e-06,
#               'cut9': 0.0,
#               'cut10': 0.0}),
#  'bkg_2018_QCD_QCD_HT1500to2000': defaultdict(float,
#              {'all': 0.0008833289564781436,
#               'hasVtx': 5.471068987195709e-06,
#               'cut2': 5.222384033232268e-06,
#               'cut3': 5.222384033232268e-06,
#               'cut4': 5.056594063923307e-06,
#               'cut5': 1.326319754471687e-06,
#               'cut6': 1.326319754471687e-06,
#               'cut7': 1.326319754471687e-06,
#               'cut8': 9.118448311992848e-07,
#               'cut9': 0.0,
#               'cut10': 0.0}),
#  'bkg_2018_Multiboson_WZZ': defaultdict(float,
#              {'all': 0.009184671448323082,
#               'hasVtx': 6.2530812186587e-05,
#               'cut2': 4.781767622128343e-05,
#               'cut3': 4.781767622128343e-05,
#               'cut4': 4.4139393970619e-05,
#               'cut5': 2.2069698725970964e-05,
#               'cut6': 2.2069698725970964e-05,
#               'cut7': 2.2069698725970964e-05,
#               'cut8': 1.839141473464507e-05,
#               'cut9': 1.1034849362985482e-05,
#               'cut10': 3.6782831209951606e-06}),
#  'bkg_2018_Multiboson_ZZ': defaultdict(float,
#              {'all': 0.000603516732841747,
#               'hasVtx': 5.104934770277935e-06,
#               'cut2': 4.537719795802609e-06,
#               'cut3': 4.537719795802609e-06,
#               'cut4': 4.254112308564946e-06,
#               'cut5': 2.836074872376631e-06,
#               'cut6': 2.836074872376631e-06,
#               'cut7': 2.836074872376631e-06,
#               'cut8': 2.836074872376631e-06,
#               'cut9': 2.836074872376631e-06,
#               'cut10': 5.672149744753261e-07}),
#  'bkg_2018_Multiboson_WWW': defaultdict(float,
#              {'all': 0.007309132126508059,
#               'hasVtx': 4.611439715299707e-05,
#               'cut2': 4.611439715299707e-05,
#               'cut3': 4.611439715299707e-05,
#               'cut4': 4.611439715299707e-05,
#               'cut5': 2.7668638753507393e-05,
#               'cut6': 2.3057198576498536e-05,
#               'cut7': 2.3057198576498536e-05,
#               'cut8': 2.3057198576498536e-05,
#               'cut9': 1.844575839948968e-05,
#               'cut10': 9.22287919974484e-06}),
#  'bkg_2018_Multiboson_WWZ': defaultdict(float,
#              {'all': 0.01059029760486389,
#               'hasVtx': 0.00012014201392296519,
#               'cut2': 0.00011569231346024389,
#               'cut3': 0.00011569231346024389,
#               'cut4': 0.00011124261299752259,
#               'cut5': 6.674558019545124e-05,
#               'cut6': 6.674558019545124e-05,
#               'cut7': 6.674558019545124e-05,
#               'cut8': 6.674558019545124e-05,
#               'cut9': 3.5597637511600433e-05,
#               'cut10': 2.224852344475027e-05}),
#  'bkg_2018_Multiboson_WZ': defaultdict(float,
#              {'all': 0.0006557934508816121,
#               'hasVtx': 4.408060453400504e-06,
#               'cut2': 4.156171284634761e-06,
#               'cut3': 4.156171284634761e-06,
#               'cut4': 3.904282115869017e-06,
#               'cut5': 2.0151133501259444e-06,
#               'cut6': 1.7632241813602015e-06,
#               'cut7': 1.7632241813602015e-06,
#               'cut8': 1.63727959697733e-06,
#               'cut9': 1.1335012594458439e-06,
#               'cut10': 0.0}),
#  'bkg_2018_TTX_TTZToLLNuNu': defaultdict(float,
#              {'all': 0.00376094261029584,
#               'hasVtx': 5.532626487807084e-05,
#               'cut2': 5.170001133507177e-05,
#               'cut3': 5.138918969396435e-05,
#               'cut4': 4.9317044356502394e-05,
#               'cut5': 1.5644692991017243e-05,
#               'cut6': 1.4919441963393687e-05,
#               'cut7': 1.4401404831468846e-05,
#               'cut8': 1.3572547653555289e-05,
#               'cut9': 1.056793819033042e-05,
#               'cut10': 3.5226457975903557e-06}),
#  'bkg_2018_Multiboson_WW': defaultdict(float,
#              {'all': 0.000621097848791001,
#               'hasVtx': 3.234884629119797e-06,
#               'cut2': 2.821920633913014e-06,
#               'cut3': 2.821920633913014e-06,
#               'cut4': 2.6154386363096227e-06,
#               'cut5': 1.1700646530858839e-06,
#               'cut6': 1.0324099880169564e-06,
#               'cut7': 9.635826554824927e-07,
#               'cut8': 9.635826554824927e-07,
#               'cut9': 5.506186602757101e-07,
#               'cut10': 2.7530933013785504e-07}),
#  'bkg_2018_DY-M50_DYJetsToLL_M-50_HT-400to600': defaultdict(float,
#              {'all': 0.003809323463703832,
#               'hasVtx': 5.085084806417669e-05,
#               'cut2': 4.680972106569907e-05,
#               'cut3': 4.6360706954757115e-05,
#               'cut4': 4.478915756646026e-05,
#               'cut5': 2.4808029629543153e-05,
#               'cut6': 2.4246761990865708e-05,
#               'cut7': 2.4246761990865708e-05,
#               'cut8': 2.4246761990865708e-05,
#               'cut9': 1.5827747410704002e-05,
#               'cut10': 5.949436969980937e-06}),
#  'bkg_2018_DY-M50_DYJetsToLL_M-50_HT-600to800': defaultdict(float,
#              {'all': 0.005809148445893253,
#               'hasVtx': 8.996626052040294e-05,
#               'cut2': 8.28599208268482e-05,
#               'cut3': 8.229141365136383e-05,
#               'cut4': 7.902249739232865e-05,
#               'cut5': 3.837423434519557e-05,
#               'cut6': 3.7521473581969e-05,
#               'cut7': 3.73793467880979e-05,
#               'cut8': 3.6810839612613526e-05,
#               'cut9': 2.089263869905092e-05,
#               'cut10': 9.38036839549225e-06}),
#  'bkg_2018_DY-M50_DYJetsToLL_M-50_HT-200to400': defaultdict(float,
#              {'all': 0.0009499494953271393,
#               'hasVtx': 7.694092421654903e-06,
#               'cut2': 7.206438676620438e-06,
#               'cut3': 7.152254927172164e-06,
#               'cut4': 6.556233683241151e-06,
#               'cut5': 3.14265746799989e-06,
#               'cut6': 2.8175549713102463e-06,
#               'cut7': 2.8175549713102463e-06,
#               'cut8': 2.8175549713102463e-06,
#               'cut9': 2.004798729586137e-06,
#               'cut10': 7.585724922758356e-07}),
#  'bkg_2018_DY-M50_DYJetsToLL_M-50_HT-800to1200': defaultdict(float,
#              {'all': 0.007947845743868406,
#               'hasVtx': 0.00011380591539189066,
#               'cut2': 0.00010646842874162403,
#               'cut3': 0.00010497098248646758,
#               'cut4': 0.00010107762222306079,
#               'cut5': 4.4324409152631105e-05,
#               'cut6': 4.402491990159981e-05,
#               'cut7': 4.402491990159981e-05,
#               'cut8': 4.297670752299029e-05,
#               'cut9': 1.9017567440486994e-05,
#               'cut10': 6.738508148204053e-06}),
#  'bkg_2018_DY-M50_DYJetsToLL_M-50_HT-100to200': defaultdict(float,
#              {'all': 2.2746070501827167e-05,
#               'hasVtx': 3.816454782185766e-08,
#               'cut2': 0.0,
#               'cut3': 0.0,
#               'cut4': 0.0,
#               'cut5': 0.0,
#               'cut6': 0.0,
#               'cut7': 0.0,
#               'cut8': 0.0,
#               'cut9': 0.0,
#               'cut10': 0.0}),
#  'bkg_2018_DY-M4to50_DYJetsToLL_M-4to50_HT-400to600': defaultdict(float,
#              {'all': 0.0004155139897111373,
#               'hasVtx': 5.728120366216113e-06,
#               'cut2': 5.406315851260151e-06,
#               'cut3': 5.406315851260151e-06,
#               'cut4': 4.891428627330613e-06,
#               'cut5': 2.83187973161246e-06,
#               'cut6': 2.7675188286212676e-06,
#               'cut7': 2.7675188286212676e-06,
#               'cut8': 2.7675188286212676e-06,
#               'cut9': 1.930827089735768e-06,
#               'cut10': 5.792481269207305e-07}),
#  'bkg_2018_DY-M4to50_DYJetsToLL_M-4to50_HT-200to400': defaultdict(float,
#              {'all': 6.353695950203887e-05,
#               'hasVtx': 7.528075770383752e-07,
#               'cut2': 7.528075770383752e-07,
#               'cut3': 7.528075770383752e-07,
#               'cut4': 7.528075770383752e-07,
#               'cut5': 3.764037885191876e-07,
#               'cut6': 3.764037885191876e-07,
#               'cut7': 3.764037885191876e-07,
#               'cut8': 3.764037885191876e-07,
#               'cut9': 1.5056151540767503e-07,
#               'cut10': 0.0}),
#  'bkg_2018_DY-M50_DYJetsToLL_M-50_HT-2500toInf': defaultdict(float,
#              {'all': 0.025889152933242947,
#               'hasVtx': 0.00019057700347234333,
#               'cut2': 0.0001834998733699221,
#               'cut3': 0.00018248885478386193,
#               'cut4': 0.00017237866892326015,
#               'cut5': 1.7187315963023005e-05,
#               'cut6': 1.7187315963023005e-05,
#               'cut7': 1.7187315963023005e-05,
#               'cut8': 1.5670788083932742e-05,
#               'cut9': 4.549583637270796e-06,
#               'cut10': 1.5165278790902654e-06}),
#  'bkg_2018_DY-M4to50_DYJetsToLL_M-4to50_HT-100to200': defaultdict(float,
#              {'all': 2.0080058500826987e-06,
#               'hasVtx': 0.0,
#               'cut2': 0.0,
#               'cut3': 0.0,
#               'cut4': 0.0,
#               'cut5': 0.0,
#               'cut6': 0.0,
#               'cut7': 0.0,
#               'cut8': 0.0,
#               'cut9': 0.0,
#               'cut10': 0.0}),
#  'bkg_2018_DY-M4to50_DYJetsToLL_M-4to50_HT-600toInf': defaultdict(float,
#              {'all': 0.0012737540155893408,
#               'hasVtx': 1.6714853167892823e-05,
#               'cut2': 1.548179022927778e-05,
#               'cut3': 1.541328673268805e-05,
#               'cut4': 1.4796755263380532e-05,
#               'cut5': 7.672391618049164e-06,
#               'cut6': 7.672391618049164e-06,
#               'cut7': 7.672391618049164e-06,
#               'cut8': 7.329874135100541e-06,
#               'cut9': 2.8771468567684364e-06,
#               'cut10': 1.1645594420253196e-06}),
#  'bkg_2018_DY-M50_DYJetsToLL_M-50_HT-1200to2500': defaultdict(float,
#              {'all': 0.012201038714728357,
#               'hasVtx': 0.00014577940252174043,
#               'cut2': 0.0001373472235104718,
#               'cut3': 0.0001355634933350111,
#               'cut4': 0.00012859072992184667,
#               'cut5': 4.426893980916033e-05,
#               'cut6': 4.410678252048209e-05,
#               'cut7': 4.410678252048209e-05,
#               'cut8': 4.1350108612951954e-05,
#               'cut9': 1.4594155981041867e-05,
#               'cut10': 6.648448835807962e-06})}

# %%
fig, ax = plt.subplots(figsize=(7,7))

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_CosThetaColl',
    'cut': 'cut9',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/',
    'outName': f'signal_cut9_coscollinear_m5to40_delta0p1_ctau100.png'
}

# signal points
m1s = [5, 10, 20, 30, 40]
deltas = [0.1]
ctaus = [100]

# Plot for variables signal points
for m1 in m1s:
    for delta in deltas:
        for ctau in ctaus:
            ptools.plot_signal_1D(sig_histo, m1, delta, ctau, plot_dict, style_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 37
#      35 for delta in deltas:
#      36     for ctau in ctaus:
# ---> 37         ptools.plot_signal_1D(sig_histo, m1, delta, ctau, plot_dict, style_dict)
#
# NameError: name 'sig_histo' is not defined

# %%
fig, ax = plt.subplots(figsize=(7,7))

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_CosThetaColl',
    'cut': 'cut9',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/',
    'outName': f'signal_cut9_coscollinear_m50to100_delta0p1_ctau100.png'
}

# signal points
m1s = [50, 70, 90, 100]
deltas = [0.1]
ctaus = [100]

# Plot for variables signal points
for m1 in m1s:
    for delta in deltas:
        for ctau in ctaus:
            ptools.plot_signal_1D(sig_histo, m1, delta, ctau, plot_dict, style_dict)
# Out:
# Saved: ./plots//signal_cut9_coscollinear_m50to100_delta0p1_ctau100.png
# Saved: ./plots//signal_cut9_coscollinear_m50to100_delta0p1_ctau100.png
# Saved: ./plots//signal_cut9_coscollinear_m50to100_delta0p1_ctau100.png
# Saved: ./plots//signal_cut9_coscollinear_m50to100_delta0p1_ctau100.png

# %%
fig, ax = plt.subplots(figsize=(7,7))

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_CosThetaColl',
    'cut': 'cut9',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/',
    'outName': f'signal_cut9_coscollinear_m5to40_delta0p2_ctau100.png'
}

# signal points
m1s = [5, 10, 20, 30, 40]
deltas = [0.2]
ctaus = [100]

# Plot for variables signal points
for m1 in m1s:
    for delta in deltas:
        for ctau in ctaus:
            ptools.plot_signal_1D(sig_histo, m1, delta, ctau, plot_dict, style_dict)
# Out:
# Saved: ./plots//signal_cut9_coscollinear_m5to40_delta0p2_ctau100.png
# Saved: ./plots//signal_cut9_coscollinear_m5to40_delta0p2_ctau100.png
# Saved: ./plots//signal_cut9_coscollinear_m5to40_delta0p2_ctau100.png
# Saved: ./plots//signal_cut9_coscollinear_m5to40_delta0p2_ctau100.png
# Saved: ./plots//signal_cut9_coscollinear_m5to40_delta0p2_ctau100.png

# %%
fig, ax = plt.subplots(figsize=(7,7))

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_CosThetaColl',
    'cut': 'cut9',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/',
    'outName': f'signal_cut9_coscollinear_m50to100_delta0p2_ctau100.png'
}

# signal points
m1s = [70, 90, 100]
deltas = [0.2]
ctaus = [100]

# Plot for variables signal points
for m1 in m1s:
    for delta in deltas:
        for ctau in ctaus:
            ptools.plot_signal_1D(sig_histo, m1, delta, ctau, plot_dict, style_dict)
# Out:
# Saved: ./plots//signal_cut9_coscollinear_m50to100_delta0p2_ctau100.png
# Saved: ./plots//signal_cut9_coscollinear_m50to100_delta0p2_ctau100.png
# Saved: ./plots//signal_cut9_coscollinear_m50to100_delta0p2_ctau100.png

# %% [markdown]
# ## Data and Background

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut3'
variable = 'lead_jet_phi_vs_lead_jet_eta'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$\phi(j_{1})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$\eta(j_{1})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

# Data
ptools.plot_data_2D(data_histo, plot_dict, style_2d_dict)


# Bkg

style_2d_dict['fig'], style_2d_dict['ax'] = plt.subplots(figsize=(7,7))
ptools.plot_bkg_2D(bkg_histo, plot_dict, style_2d_dict, processes = 'all')
# Out:
# Saved: ./plots/VR_localHEMveto/data/sel_vtx//data_VR_lead_jet_phi_vs_lead_jet_eta_cut3.png
# Saved: ./plots/VR_localHEMveto/data/sel_vtx//data_VR_lead_jet_phi_vs_lead_jet_eta_cut3.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut4'
variable = 'sel_e1_phi_vs_sel_e1_eta'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$\phi(e_{1})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$\eta(e_{1})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

# Data
ptools.plot_data_2D(data_histo, plot_dict, style_2d_dict)


# Bkg

style_2d_dict['fig'], style_2d_dict['ax'] = plt.subplots(figsize=(7,7))
ptools.plot_bkg_2D(bkg_histo, plot_dict, style_2d_dict, processes = 'all')
# Out:
# Saved: ./plots/VR_localHEMveto/data/sel_vtx//data_VR_sel_e1_phi_vs_sel_e1_eta_cut4.png
# Saved: ./plots/VR_localHEMveto/data/sel_vtx//data_VR_sel_e1_phi_vs_sel_e1_eta_cut4.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut3'
variable = 'sel_e2_phi_vs_sel_e2_eta'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$\phi(e_{2})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$\eta(e_{2})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

# Data
ptools.plot_data_2D(data_histo, plot_dict, style_2d_dict)


# Bkg

style_2d_dict['fig'], style_2d_dict['ax'] = plt.subplots(figsize=(7,7))
ptools.plot_bkg_2D(bkg_histo, plot_dict, style_2d_dict, processes = 'all')

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut4'
variable = 'sel_vtx_phi_vs_sel_vtx_eta'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$\phi(SV)$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$\eta(SV)$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

# Data
ptools.plot_data_2D(data_histo, plot_dict, style_2d_dict)


# Bkg

style_2d_dict['fig'], style_2d_dict['ax'] = plt.subplots(figsize=(7,7))
ptools.plot_bkg_2D(bkg_histo, plot_dict, style_2d_dict, processes = 'all')
# Out:
# Saved: ./plots/VR_localHEMveto/data/sel_vtx//data_VR_sel_vtx_phi_vs_sel_vtx_eta_cut4.png
# Saved: ./plots/VR_localHEMveto/data/sel_vtx//data_VR_sel_vtx_phi_vs_sel_vtx_eta_cut4.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut4'
variable = 'sel_vtx_phi_vs_METphi'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$\phi(SV)$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$\phi(MET)$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

# Data
ptools.plot_data_2D(data_histo, plot_dict, style_2d_dict)


# Bkg

style_2d_dict['fig'], style_2d_dict['ax'] = plt.subplots(figsize=(7,7))
ptools.plot_bkg_2D(bkg_histo, plot_dict, style_2d_dict, processes = 'all')
# Out:
# Saved: ./plots/VR_localHEMveto/data/sel_vtx//data_VR_sel_vtx_phi_vs_METphi_cut4.png
# Saved: ./plots/VR_localHEMveto/data/sel_vtx//data_VR_sel_vtx_phi_vs_METphi_cut4.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut3'
variable = 'sel_vtx_phi_refit_vs_METphi'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$\phi_{refit}(SV)$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$\phi(MET)$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

# Data
ptools.plot_data_2D(data_histo, plot_dict, style_2d_dict)


# Bkg

style_2d_dict['fig'], style_2d_dict['ax'] = plt.subplots(figsize=(7,7))
ptools.plot_bkg_2D(bkg_histo, plot_dict, style_2d_dict, processes = 'all')
# Out:
# Saved: ./plots/VR_localHEMveto/data/sel_vtx//data_VR_sel_vtx_phi_refit_vs_METphi_cut3.png
# Saved: ./plots/VR_localHEMveto/data/sel_vtx//data_VR_sel_vtx_phi_refit_vs_METphi_cut3.png

# %%
variable = 'sel_vtx_phi'
cut = 'cut9'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 8j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

# ISR cut
cut = 'cut9'
#style_dict['fig'], style_dict['ax'] = plt.subplots(figsize=(6,6))
plot_dict['cut'] = cut
style_dict['outName'] = f'data_VR_{variable}_{cut}.png'
ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)

# VR cut
cut = 'cut9'
style_dict['fig'], style_dict['ax'] = plt.subplots(figsize=(6,6))
plot_dict['cut'] = cut
style_dict['outName'] = f'data_VR_{variable}_{cut}.png'
ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots/VR_localHEMveto/data_bkg/sel_vtx//data_VR_sel_vtx_phi_cut9.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots/VR_localHEMveto/data_bkg/sel_vtx//data_VR_sel_vtx_phi_cut9.png
# Saved: ./plots/VR_localHEMveto/data_bkg/sel_vtx//data_VR_sel_vtx_phi_cut9.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots/VR_localHEMveto/data_bkg/sel_vtx//data_VR_sel_vtx_phi_cut9.png

# %%
variable = 'sel_vtx_phi'
cut = 'cut9'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 8j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

# ISR cut
cut = 'cut9'
#style_dict['fig'], style_dict['ax'] = plt.subplots(figsize=(6,6))
plot_dict['cut'] = cut
style_dict['outName'] = f'data_VR_{variable}_{cut}.png'
ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)

# VR cut
cut = 'cut9'
style_dict['fig'], style_dict['ax'] = plt.subplots(figsize=(6,6))
plot_dict['cut'] = cut
style_dict['outName'] = f'data_VR_{variable}_{cut}.png'
ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots/VR_localHEMveto/data_bkg/sel_vtx//data_VR_sel_vtx_phi_cut9.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots/VR_localHEMveto/data_bkg/sel_vtx//data_VR_sel_vtx_phi_cut9.png
# Saved: ./plots/VR_localHEMveto/data_bkg/sel_vtx//data_VR_sel_vtx_phi_cut9.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots/VR_localHEMveto/data_bkg/sel_vtx//data_VR_sel_vtx_phi_cut9.png

# %%
variable = 'lead_jet_phi'
cut = 'cut5'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 5j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$\phi(j_{1})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots/VR_bugHEMveto/data_bkg/sel_vtx//data_VR_lead_jet_phi_cut5.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots/VR_bugHEMveto/data_bkg/sel_vtx//data_VR_lead_jet_phi_cut5.png

# %%
variable = 'lead_jet_eta'
cut = 'cut5'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 8j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$\eta(j_{1})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots/VR_bugHEMveto/data_bkg/sel_vtx//data_VR_lead_jet_eta_cut5.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots/VR_bugHEMveto/data_bkg/sel_vtx//data_VR_lead_jet_eta_cut5.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut5'
variable = 'lead_jet_phi_vs_lead_jet_eta'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$\phi(j_{1})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$\eta(j_{1})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/bkg/sel_vtx/',
    'outName': f'bkg_VR_{variable}_{cut}.png'
}

ptools.plot_bkg_2D(bkg_histo, plot_dict, style_2d_dict, processes = 'all')
# Out:
# Saved: ./plots/VR_bugHEMveto/bkg/sel_vtx//bkg_VR_lead_jet_phi_vs_lead_jet_eta_cut5.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut5'
variable = 'lead_jet_phi_vs_lead_jet_eta'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$\phi(j_{1})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$\eta(j_{1})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

ptools.plot_data_2D(data_histo, plot_dict, style_2d_dict)
# Out:
# Saved: ./plots/VR_bugHEMveto/data/sel_vtx//data_VR_lead_jet_phi_vs_lead_jet_eta_cut5.png

# %%
variable = 'jetMETdPhi'
cut = 'cut10'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 5j,
    'xlim': [1.5,4],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"|$\Delta\phi(j_{1}, p^{miss}_{T})$|",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data_bkg/jetMET/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots/VR_bugHEMveto/data_bkg/jetMET//data_VR_jetMETdPhi_cut10.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots/VR_bugHEMveto/data_bkg/jetMET//data_VR_jetMETdPhi_cut10.png

# %%
variable = 'PFMETphi'
cut = 'cut5'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 5j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$\phi(PF MET)$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data_bkg/jetMET/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots/VR_bugHEMveto/data_bkg/jetMET//data_VR_PFMETphi_cut5.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots/VR_bugHEMveto/data_bkg/jetMET//data_VR_PFMETphi_cut5.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut9'
variable = 'METphi_vs_lead_jet_phi'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$\phi(PF MET)$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$\phi(j_{1})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data/jetMET/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

ptools.plot_data_2D(data_histo, plot_dict, style_2d_dict)
# Out:
# Saved: ./plots/VR_bugHEMveto/data/jetMET//data_VR_METphi_vs_lead_jet_phi_cut9.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut9'
variable = 'METphi_vs_lead_jet_phi'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$\phi(PF MET)$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$\phi(j_{1})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/bkg/jetMET/',
    'outName': f'bkg_VR_{variable}_{cut}.png'
}

ptools.plot_bkg_2D(bkg_histo, plot_dict, style_2d_dict, processes = 'all')
# Out:
# Saved: ./plots/VR_bugHEMveto/bkg/jetMET//bkg_VR_METphi_vs_lead_jet_phi_cut9.png

# %%
variable = 'sel_vtx_phi'
cut = 'cut9'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 5j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$\phi(vtx(e_{1},e_{2}))$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots/VR_bugHEMveto/data_bkg/sel_vtx//data_VR_sel_vtx_phi_cut9.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots/VR_bugHEMveto/data_bkg/sel_vtx//data_VR_sel_vtx_phi_cut9.png

# %%
variable = 'sel_vtx_eta'
cut = 'cut10'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 8j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$\eta(vtx(e_{1},e_{2}))$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots/VR_bugHEMveto/data_bkg/sel_vtx//data_VR_sel_vtx_eta_cut10.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots/VR_bugHEMveto/data_bkg/sel_vtx//data_VR_sel_vtx_eta_cut10.png

# %%
variable = 'sel_vtx_METdPhi'
cut = 'cut9'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 10j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"|$\Delta\phi(vtx(e_{1},e_{2}), p^{miss}_{T})$|",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots/VR_bugHEMveto/data_bkg/sel_vtx//data_VR_sel_vtx_METdPhi_cut9.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots/VR_bugHEMveto/data_bkg/sel_vtx//data_VR_sel_vtx_METdPhi_cut9.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut9'
variable = 'sel_vtx_phi_vs_lead_jet_phi'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$\phi(vtx(e_{1},e_{2}))$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$\phi(j_{1})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

ptools.plot_data_2D(data_histo, plot_dict, style_2d_dict)
# Out:
# Saved: ./plots/VR_bugHEMveto/data/sel_vtx//data_VR_sel_vtx_phi_vs_lead_jet_phi_cut9.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut9'
variable = 'sel_vtx_phi_vs_lead_jet_phi'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$\phi(vtx(e_{1},e_{2}))$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$\phi(j_{1})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/bkg/sel_vtx/',
    'outName': f'bkg_VR_{variable}_{cut}.png'
}

ptools.plot_bkg_2D(bkg_histo, plot_dict, style_2d_dict, processes = 'all')
# Out:
# Saved: ./plots/VR_bugHEMveto/bkg/sel_vtx//bkg_VR_sel_vtx_phi_vs_lead_jet_phi_cut9.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut9'
variable = 'sel_vtx_phi_vs_METphi'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$\phi(vtx(e_{1},e_{2}))$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$\phi(PF MET)$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

ptools.plot_data_2D(data_histo, plot_dict, style_2d_dict)
# Out:
# Saved: ./plots/VR_bugHEMveto/data/sel_vtx//data_VR_sel_vtx_phi_vs_METphi_cut9.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut9'
variable = 'sel_vtx_phi_vs_METphi'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$\phi(vtx(e_{1},e_{2}))$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$\phi(PF MET)$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/bkg/sel_vtx/',
    'outName': f'bkg_VR_{variable}_{cut}.png'
}

ptools.plot_bkg_2D(bkg_histo, plot_dict, style_2d_dict, processes = 'all')
# Out:
# Saved: ./plots/VR_bugHEMveto/bkg/sel_vtx//bkg_VR_sel_vtx_phi_vs_METphi_cut9.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut9'
variable = 'sel_vtx_phi_vs_sel_vtx_eta'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$\phi(vtx(e_{1},e_{2}))$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$\eta(vtx(e_{1},e_{2}))$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

ptools.plot_data_2D(data_histo, plot_dict, style_2d_dict)
# Out:
# Saved: ./plots/VR_bugHEMveto/data/sel_vtx//data_VR_sel_vtx_phi_vs_sel_vtx_eta_cut9.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut9'
variable = 'sel_vtx_phi_vs_sel_vtx_eta'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$\phi(vtx(e_{1},e_{2}))$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$\eta(vtx(e_{1},e_{2}))$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/bkg/sel_vtx/',
    'outName': f'bkg_VR_{variable}_{cut}.png'
}

ptools.plot_bkg_2D(bkg_histo, plot_dict, style_2d_dict, processes = 'all')
# Out:
# Saved: ./plots/VR_bugHEMveto/bkg/sel_vtx//bkg_VR_sel_vtx_phi_vs_sel_vtx_eta_cut9.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut9'
variable = 'sel_vtx_phi_vs_sel_vtx_pt800'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$\phi(vtx(e_{1},e_{2}))$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$pT(vtx(e_{1},e_{2}))$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

ptools.plot_data_2D(data_histo, plot_dict, style_2d_dict)
# Out:
# Saved: ./plots/VR_bugHEMveto/data/sel_vtx//data_VR_sel_vtx_phi_vs_sel_vtx_pt800_cut9.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut9'
variable = 'sel_vtx_phi_vs_sel_vtx_pt'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$\phi(vtx(e_{1},e_{2}))$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$pT(vtx(e_{1},e_{2}))$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

ptools.plot_data_2D(data_histo, plot_dict, style_2d_dict)
# Out:
# Saved: ./plots/VR_bugHEMveto/data/sel_vtx//data_VR_sel_vtx_phi_vs_sel_vtx_pt_cut9.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut9'
variable = 'sel_vtx_phi_vs_sel_vtx_pt'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$\phi(vtx(e_{1},e_{2}))$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$pT(vtx(e_{1},e_{2}))$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/bkg/sel_vtx/',
    'outName': f'bkg_VR_{variable}_{cut}.png'
}

ptools.plot_bkg_2D(bkg_histo, plot_dict, style_2d_dict, processes = 'all')
# Out:
# Saved: ./plots/VR_bugHEMveto/bkg/sel_vtx//bkg_VR_sel_vtx_phi_vs_sel_vtx_pt_cut9.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut9'
variable = 'sel_vtx_phi_vs_sel_vtx_dR'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$\phi(vtx(e_{1},e_{2}))$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$dR(e_{1},e_{2}))$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

ptools.plot_data_2D(data_histo, plot_dict, style_2d_dict)
# Out:
# Saved: ./plots/VR_bugHEMveto/data/sel_vtx//data_VR_sel_vtx_phi_vs_sel_vtx_dR_cut9.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut9'
variable = 'sel_vtx_phi_vs_sel_vtx_dR'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$\phi(vtx(e_{1},e_{2}))$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$dR(e_{1},e_{2}))$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/bkg/sel_vtx/',
    'outName': f'bkg_VR_{variable}_{cut}.png'
}

ptools.plot_bkg_2D(bkg_histo, plot_dict, style_2d_dict, processes = 'all')
# Out:
# Saved: ./plots/VR_bugHEMveto/bkg/sel_vtx//bkg_VR_sel_vtx_phi_vs_sel_vtx_dR_cut9.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut9'
variable = 'sel_vtx_phi_refit_zoom_vs_sel_vtx_phi_zoom'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"Refitted $\phi(vtx(e_{1},e_{2}))$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$\phi(vtx(e_{1},e_{2}))$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

ptools.plot_data_2D(data_histo, plot_dict, style_2d_dict)
# Out:
# Saved: ./plots/VR_bugHEMveto/data/sel_vtx//data_VR_sel_vtx_phi_refit_zoom_vs_sel_vtx_phi_zoom_cut9.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut9'
variable = 'sel_vtx_phi_refit_vs_sel_vtx_phi'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"Refitted $\phi(vtx(e_{1},e_{2}))$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$\phi(vtx(e_{1},e_{2}))$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

ptools.plot_data_2D(data_histo, plot_dict, style_2d_dict)
# Out:
# Saved: ./plots/VR_bugHEMveto/data/sel_vtx//data_VR_sel_vtx_phi_refit_vs_sel_vtx_phi_cut9.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut9'
variable = 'sel_vtx_phi_refit_vs_sel_vtx_phi'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"Refitted $\phi(vtx(e_{1},e_{2}))$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$\phi(vtx(e_{1},e_{2}))$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/bkg/sel_vtx/',
    'outName': f'bkg_VR_{variable}_{cut}.png'
}

ptools.plot_bkg_2D(bkg_histo, plot_dict, style_2d_dict, processes = 'all')
# Out:
# Saved: ./plots/VR_bugHEMveto/bkg/sel_vtx//bkg_VR_sel_vtx_phi_refit_vs_sel_vtx_phi_cut9.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut9'
variable = 'sel_e1_phi_vs_METphi'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$\phi(e_{1})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$\phi(PF MET)$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

ptools.plot_data_2D(data_histo, plot_dict, style_2d_dict)
# Out:
# Saved: ./plots/VR_bugHEMveto/data/sel_vtx//data_VR_sel_e1_phi_vs_METphi_cut9.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut9'
variable = 'sel_e1_phi_vs_METphi'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$\phi(e_{1})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$\phi(PF MET)$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/bkg/sel_vtx/',
    'outName': f'bkg_VR_{variable}_{cut}.png'
}

ptools.plot_bkg_2D(bkg_histo, plot_dict, style_2d_dict, processes = 'all')
# Out:
# Saved: ./plots/VR_bugHEMveto/bkg/sel_vtx//bkg_VR_sel_e1_phi_vs_METphi_cut9.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut9'
variable = 'sel_e1_phi_vs_sel_e1_eta'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$\phi(e_{1})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$\eta(e_{1})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

ptools.plot_data_2D(data_histo, plot_dict, style_2d_dict)
# Out:
# Saved: ./plots/VR_bugHEMveto/data/sel_vtx//data_VR_sel_e1_phi_vs_sel_e1_eta_cut9.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut9'
variable = 'sel_e1_phi_zoom_vs_sel_e1_eta'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$\phi(e_{1})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$\eta(e_{1})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

ptools.plot_data_2D(data_histo, plot_dict, style_2d_dict)
# Out:
# Saved: ./plots/VR_bugHEMveto/data/sel_vtx//data_VR_sel_e1_phi_zoom_vs_sel_e1_eta_cut9.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut9'
variable = 'sel_e1_phi_vs_sel_e1_eta'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$\phi(e_{1})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$\eta(e_{1})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/bkg/sel_vtx/',
    'outName': f'bkg_VR_{variable}_{cut}.png'
}

ptools.plot_bkg_2D(bkg_histo, plot_dict, style_2d_dict, processes = 'all')
# Out:
# Saved: ./plots/VR_bugHEMveto/bkg/sel_vtx//bkg_VR_sel_e1_phi_vs_sel_e1_eta_cut9.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut9'
variable = 'sel_e1_phi_vs_sel_e1_pt'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$\phi(e_{1})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$pT(e_{1})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

ptools.plot_data_2D(data_histo, plot_dict, style_2d_dict)
# Out:
# Saved: ./plots/VR_bugHEMveto/data/sel_vtx//data_VR_sel_e1_phi_vs_sel_e1_pt_cut9.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut9'
variable = 'sel_e1_phi_vs_sel_e1_pt'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$\phi(e_{1})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$pT(e_{1})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/bkg/sel_vtx/',
    'outName': f'bkg_VR_{variable}_{cut}.png'
}

ptools.plot_bkg_2D(bkg_histo, plot_dict, style_2d_dict, processes = 'all')
# Out:
# Saved: ./plots/VR_bugHEMveto/bkg/sel_vtx//bkg_VR_sel_e1_phi_vs_sel_e1_pt_cut9.png

# %%
variable = 'sel_vtx_phi_refit_over_phi'
cut = 'cut9'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': [0.2,1.8],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"Refitted ee-vtx phi / ee-vtx phi",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)

# %%
fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': 'nJets',
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': 'n(PF Jets)',   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/jetMET/',
    'outName': 'data_background_nJet.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/jetMET//data_background_nJet.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms_data/d3/kyungmip/CMSSW_10_6_26/src/iDMe/python_analysis/studies/VRstudies/../../analysisTools/plotTools.py:1357: RuntimeWarning: invalid value encountered in divide
#   ratio = hist_data.values()/hist_bkg.values()
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/jetMET//data_background_nJet.png

# %%
variable = 'sel_vtx_mass'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut9',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 5j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"m($e_{1}$,$e_{2}$) [GeV]",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events/1.5GeV',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_mass.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_mass.png

# %%
variable = 'sel_vtx_dR'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 4j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$\Delta$R($e_{1},e_{2}$)",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events/0.2',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_dR.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_dR.png

# %%
variable = 'sel_vtx_mindxy'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': [0,0.2],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"min($|d_{xy}(e_{1})|,|d_{xy}(e_{2})|$) [cm]",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events/0.01cm',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_mindxy.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_mindxy.png

# %%
cut_map = {}

for idx, cut_idx in enumerate(utils.get_signal_list_of_cuts(sig_histo, get_cut_idx = True)):
    cut_map[cut_idx] = utils.get_signal_list_of_cuts(sig_histo)[idx]

print(cut_map)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 cut_map = {}
# ----> 3 for idx, cut_idx in enumerate(utils.get_signal_list_of_cuts(sig_histo, get_cut_idx = True)):
#       4     cut_map[cut_idx] = utils.get_signal_list_of_cuts(sig_histo)[idx]
#       6 print(cut_map)
#
# NameError: name 'sig_histo' is not defined

# %%
variable = 'sel_vtx_vxy1'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut7',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 3j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$L_{xy}(e_{1},e_{2})$ [cm]",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events/0.03cm',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/Lxy/',
    'outName': f'data_VR_{variable}_cut_j1pt_80.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)

'''
for cut in cut_map.keys():
    if 'all' in cut or 'hasVtx' in cut:
        continue
    
    fig, ax = plt.subplots(figsize=(6,6))
    
    style_dict['fig'] = fig
    style_dict['ax'] = ax

    plot_dict['cut'] = cut

    print(f'data_VR_{variable}_cut_{cut_map[cut].replace(" ","_")}')
    style_dict['outName'] = f'data_VR_{variable}_cut_{cut_map[cut].replace(" ","_")}'
    
    ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
'''
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/Lxy//data_VR_sel_vtx_vxy1_cut_j1pt_80.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/Lxy//data_VR_sel_vtx_vxy1_cut_j1pt_80.png
# '\nfor cut in cut_map.keys():\n    if \'all\' in cut or \'hasVtx\' in cut:\n        continue\n    \n    fig, ax = plt.subplots(figsize=(6,6))\n    \n    style_dict[\'fig\'] = fig\n    style_dict[\'ax\'] = ax\n\n    plot_dict[\'cut\'] = cut\n\n    print(f\'data_VR_{variable}_cut_{cut_map[cut].replace(" ","_")}\')\n    style_dict[\'outName\'] = f\'data_VR_{variable}_cut_{cut_map[cut].replace(" ","_")}\'\n    \n    ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)\n'

# %%
variable = 'sel_vtx_vxy10'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': [0,5],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$L_{xy}(e_{1},e_{2})$ [cm]",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events/0.1cm',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_vxy10.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms_data/d3/kyungmip/CMSSW_10_6_26/src/iDMe/python_analysis/studies/VRstudies/../../analysisTools/plotTools.py:1357: RuntimeWarning: divide by zero encountered in divide
#   ratio = hist_data.values()/hist_bkg.values()
# /uscms_data/d3/kyungmip/CMSSW_10_6_26/src/iDMe/python_analysis/studies/VRstudies/../../analysisTools/plotTools.py:1357: RuntimeWarning: invalid value encountered in divide
#   ratio = hist_data.values()/hist_bkg.values()
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_vxy10.png

# %%
variable = 'sel_vtx_vxy100'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': [0,20],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$L_{xy}(e_{1},e_{2})$ [cm]",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events/1cm',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_vxy100.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms_data/d3/kyungmip/CMSSW_10_6_26/src/iDMe/python_analysis/studies/VRstudies/../../analysisTools/plotTools.py:1357: RuntimeWarning: divide by zero encountered in divide
#   ratio = hist_data.values()/hist_bkg.values()
# /uscms_data/d3/kyungmip/CMSSW_10_6_26/src/iDMe/python_analysis/studies/VRstudies/../../analysisTools/plotTools.py:1357: RuntimeWarning: invalid value encountered in divide
#   ratio = hist_data.values()/hist_bkg.values()
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_vxy100.png

# %%
variable = 'sel_vtx_METdPhi'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 8j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"|$\Delta\phi(p^{miss}_{T},vtx)$|",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_METdPhi.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_METdPhi.png

# %%
variable = 'sel_vtx_chi2'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 5j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$\chi^{2}/ndf(vtx)$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events/0.25',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_chi2.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_chi2.png

# %%
variable = 'sel_vtx_pt'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 7j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$p_{T}(vtx)$ [GeV]",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events/3.5GeV',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_pt.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_pt.png

# %%
variable = 'sel_vtx_eta'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 8j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$\eta(vtx)$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_eta.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_eta.png

# %%
variable = 'sel_vtx_phi'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 4j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$\phi(vtx)$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_phi.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_phi.png

# %%
variable = 'sel_vtx_type'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': 'vtx Type: [LL, LR, RR]',   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_type.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_type.png

# %%
variable = 'sel_vtx_minEleDrJ'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 5j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"min($\Delta R(e_{1},j_{1}),\Delta R(e_{2},j_{2}$))",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events/0.25',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_minEleDrJ.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms_data/d3/kyungmip/CMSSW_10_6_26/src/iDMe/python_analysis/studies/VRstudies/../../analysisTools/plotTools.py:1357: RuntimeWarning: invalid value encountered in divide
#   ratio = hist_data.values()/hist_bkg.values()
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_minEleDrJ.png

# %%
variable = 'sel_vtx_mindxy_low'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 30j,
    'xlim': [0,0.05],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"min(|dxy($e_{1}$)|,|dxy($e_{2}$)|) [cm]",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_mindxy_low.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms_data/d3/kyungmip/CMSSW_10_6_26/src/iDMe/python_analysis/studies/VRstudies/../../analysisTools/plotTools.py:1357: RuntimeWarning: invalid value encountered in divide
#   ratio = hist_data.values()/hist_bkg.values()
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_mindxy_low.png

# %%
variable = 'sel_vtx_sign_etaProd'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"sign($\eta(e_{1}) \cdot \eta(e_{2})$)",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_sign_etaProd.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_sign_etaProd.png

# %%
variable = 'sel_vtx_CosThetaColl'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 5j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"cos(collinear angle)",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events/0.1',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}_moreMC.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots/data_bkg/sel_vtx//data_VR_sel_vtx_CosThetaColl_moreMC.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms_data/d3/kyungmip/CMSSW_10_6_26/src/iDMe/python_analysis/studies/VRstudies/../../analysisTools/plotTools.py:1357: RuntimeWarning: invalid value encountered in divide
#   ratio = hist_data.values()/hist_bkg.values()
# Saved: ./plots/data_bkg/sel_vtx//data_VR_sel_vtx_CosThetaColl_moreMC.png

# %%
variable = 'sel_vtx_maxMiniRelIsoCorr'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': [0,1.2],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': 'max(miniRelIsoCorr($e_{1}$), miniRelIsoCorr($e_{2}$))',   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events/0.05',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_maxMiniRelIsoCorr.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms_data/d3/kyungmip/CMSSW_10_6_26/src/iDMe/python_analysis/studies/VRstudies/../../analysisTools/plotTools.py:1357: RuntimeWarning: invalid value encountered in divide
#   ratio = hist_data.values()/hist_bkg.values()
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/sel_vtx//data_VR_sel_vtx_maxMiniRelIsoCorr.png

# %%
variable = 'PFMET'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 5j,
    'xlim': [180,500],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$p^{miss}_{T}$ [GeV]",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/jetMET/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/jetMET//data_VR_PFMET.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms_data/d3/kyungmip/CMSSW_10_6_26/src/iDMe/python_analysis/studies/VRstudies/../../analysisTools/plotTools.py:1357: RuntimeWarning: invalid value encountered in divide
#   ratio = hist_data.values()/hist_bkg.values()
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/jetMET//data_VR_PFMET.png

# %%
variable = 'PFMET1000'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 2j,
    'xlim': [180,600],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$p^{miss}_{T}$ [GeV]",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events/5GeV',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/jetMET/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/jetMET//data_VR_PFMET1000.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms_data/d3/kyungmip/CMSSW_10_6_26/src/iDMe/python_analysis/studies/VRstudies/../../analysisTools/plotTools.py:1357: RuntimeWarning: invalid value encountered in divide
#   ratio = hist_data.values()/hist_bkg.values()
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/jetMET//data_VR_PFMET1000.png

# %%
variable = 'PFMETphi'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut5',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 2j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/jetMET/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/jetMET//data_VR_PFMETphi.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/jetMET//data_VR_PFMETphi.png

# %%
variable = 'PVx'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': [-0.2,0.3],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': 'PV x [cm]',   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg//data_VR_PVx.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms_data/d3/kyungmip/CMSSW_10_6_26/src/iDMe/python_analysis/studies/VRstudies/../../analysisTools/plotTools.py:1357: RuntimeWarning: divide by zero encountered in divide
#   ratio = hist_data.values()/hist_bkg.values()
# /uscms_data/d3/kyungmip/CMSSW_10_6_26/src/iDMe/python_analysis/studies/VRstudies/../../analysisTools/plotTools.py:1357: RuntimeWarning: invalid value encountered in divide
#   ratio = hist_data.values()/hist_bkg.values()
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg//data_VR_PVx.png

# %%
variable = 'PVy'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': [-0.3, 0.2],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': 'PV y [cm]',   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg//data_VR_PVy.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms_data/d3/kyungmip/CMSSW_10_6_26/src/iDMe/python_analysis/studies/VRstudies/../../analysisTools/plotTools.py:1357: RuntimeWarning: divide by zero encountered in divide
#   ratio = hist_data.values()/hist_bkg.values()
# /uscms_data/d3/kyungmip/CMSSW_10_6_26/src/iDMe/python_analysis/studies/VRstudies/../../analysisTools/plotTools.py:1357: RuntimeWarning: invalid value encountered in divide
#   ratio = hist_data.values()/hist_bkg.values()
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg//data_VR_PVy.png

# %%
variable = 'sel_e1_dxy'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': [0,0.2],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$dxy(e_{1})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg//data_VR_sel_e1_dxy.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg//data_VR_sel_e1_dxy.png

# %%
variable = 'sel_e2_dxy'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': [0,0.2],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$dxy(e_{2})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg//data_VR_sel_e2_dxy.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg//data_VR_sel_e2_dxy.png

# %%
variable = 'sel_e1_vxy1'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$vxy(e_{1})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg//data_VR_sel_e1_vxy1.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms_data/d3/kyungmip/CMSSW_10_6_26/src/iDMe/python_analysis/studies/VRstudies/../../analysisTools/plotTools.py:1357: RuntimeWarning: divide by zero encountered in divide
#   ratio = hist_data.values()/hist_bkg.values()
# /uscms_data/d3/kyungmip/CMSSW_10_6_26/src/iDMe/python_analysis/studies/VRstudies/../../analysisTools/plotTools.py:1357: RuntimeWarning: invalid value encountered in divide
#   ratio = hist_data.values()/hist_bkg.values()
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg//data_VR_sel_e1_vxy1.png

# %%
variable = 'sel_e2_vxy1'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$vxy(e_{2})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg//data_VR_sel_e2_vxy1.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms_data/d3/kyungmip/CMSSW_10_6_26/src/iDMe/python_analysis/studies/VRstudies/../../analysisTools/plotTools.py:1357: RuntimeWarning: divide by zero encountered in divide
#   ratio = hist_data.values()/hist_bkg.values()
# /uscms_data/d3/kyungmip/CMSSW_10_6_26/src/iDMe/python_analysis/studies/VRstudies/../../analysisTools/plotTools.py:1357: RuntimeWarning: invalid value encountered in divide
#   ratio = hist_data.values()/hist_bkg.values()
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg//data_VR_sel_e2_vxy1.png

# %%
variable = 'sel_e1_vz'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 22j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$vz(e_{1})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg//data_VR_sel_e1_vz.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg//data_VR_sel_e1_vz.png

# %%
variable = 'sel_e2_vz'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 25j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$vz(e_{2})$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg//data_VR_sel_e2_vz.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg//data_VR_sel_e2_vz.png

# %%
variable = 'sel_vtx_mass_low'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut7',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 2j,
    'xlim': [0,1],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': 'm(e1,e2) [GeV]',   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/',
    'outName': f'data_VR_{variable}_cut7.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg//data_VR_sel_vtx_mass_low_cut7.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg//data_VR_sel_vtx_mass_low_cut7.png

# %%
variable = 'sel_vtx_mass_low'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut9',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 2j,
    'xlim': [0,1],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': 'm(e1,e2) [GeV]',   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/',
    'outName': f'data_VR_{variable}_cut9.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg//data_VR_sel_vtx_mass_low_cut9.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg//data_VR_sel_vtx_mass_low_cut9.png

# %%
variable = 'sel_vtx_mass_low'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut9',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 10j,
    'xlim': [1,5],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/',
    'outName': f'data_VR_{variable}_ISRcuts.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg//data_VR_sel_vtx_mass_low_ISRcuts.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg//data_VR_sel_vtx_mass_low_ISRcuts.png

# %%
variable = 'jetMETdPhi'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 3j,
    'xlim': [1.5, 4],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"|$\Delta\phi(j_{1}, p^{miss}_{T})$|",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events/0.096',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/jetMET/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/jetMET//data_VR_jetMETdPhi.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/jetMET//data_VR_jetMETdPhi.png

# %%
variable = 'minJetMETdPhi'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 4j,
    'xlim': [0.7, 4],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2//data_VR_minJetMETdPhi.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms_data/d3/kyungmip/CMSSW_10_6_26/src/iDMe/python_analysis/studies/VRstudies/../../analysisTools/plotTools.py:1357: RuntimeWarning: invalid value encountered in divide
#   ratio = hist_data.values()/hist_bkg.values()
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2//data_VR_minJetMETdPhi.png

# %%
variable = 'lead_jet_pt'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 2j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$p_{T}(j_{1})$ [GeV]",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events/18GeV',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/jetMET/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/jetMET//data_VR_lead_jet_pt.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms_data/d3/kyungmip/CMSSW_10_6_26/src/iDMe/python_analysis/studies/VRstudies/../../analysisTools/plotTools.py:1357: RuntimeWarning: invalid value encountered in divide
#   ratio = hist_data.values()/hist_bkg.values()
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/jetMET//data_VR_lead_jet_pt.png

# %%
variable = 'lead_jet_eta'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 3j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$\eta(j_{1})$ [GeV]",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events/0.15',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/data_bkg/jetMET/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots/data_bkg/jetMET//data_VR_lead_jet_eta.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# Saved: ./plots/data_bkg/jetMET//data_VR_lead_jet_eta.png

# %%
variable = 'lead_jet_phi'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$\eta(j_{1})$ [GeV]",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/jetMET/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)

# %%
variable = 'jetMETratio'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': 'cut10',
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 4j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$j_{1}/p^{miss}_{T}$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events/0.08',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/data_bkg/jetMET/',
    'outName': f'data_VR_{variable}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/jetMET//data_VR_jetMETratio.png
# /uscms/home/kyungmip/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms_data/d3/kyungmip/CMSSW_10_6_26/src/iDMe/python_analysis/studies/VRstudies/../../analysisTools/plotTools.py:1357: RuntimeWarning: invalid value encountered in divide
#   ratio = hist_data.values()/hist_bkg.values()
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2/data_bkg/jetMET//data_VR_jetMETratio.png

# %% [markdown]
# ### Plot 2D -- Background

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

plot_dict = {
    'variable': 'sel_vtx_vx_vs_vy',
    'cut': 'cut9',
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$v_{x}$ [cm]",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$v_{y}$ [cm]",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/',
    'outName': f'background_cut9_vx_vs_vy_all.png'
}

ptools.plot_bkg_2D(bkg_histo, plot_dict, style_2d_dict, processes = 'all')
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2//background_cut7_vx_vs_vy_all.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

plot_dict = {
    'variable': 'sel_vtx_vx_vs_vy',
    'cut': 'cut9',
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': [-1,1],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': [-1,1],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$v_{x}$ [cm]",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$v_{y}$ [cm]",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots{suffix}/',
    'outName': f'background_cut9_vx_vs_vy_all.png'
}

ptools.plot_bkg_2D(bkg_histo, plot_dict, style_2d_dict, processes = 'all')
# Out:
# Saved: ./plots_VR_collinear_neg_good_vtx_v7_NJetG2//background_cut9_vx_vs_vy_all.png

# %%
# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

plot_dict = {
    'variable': 'sel_vtx_vx_vs_vy',
    'cut': 'cut9',
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$v_{x}$ [cm]",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$v_{y}$ [cm]",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/',
    'outName': f'background_cut7_vx_vs_vy_WZjets.png'
}

ptools.plot_bkg_2D(bkg_histo, plot_dict, style_2d_dict, processes = ['WJets', 'ZJets'])
# Out:
# Saved: ./plots//background_cut7_vx_vs_vy_WZjets.png

# %% [markdown]
# ### Plot 2D -- Signal

# %%
m1 = 30
delta = 0.1
ctau = 100

# Plot settings
fig, ax = plt.subplots(figsize=(7,7))

plot_dict = {
    'variable': 'sel_vtx_vx_vs_vy',
    'cut': 'cut9',
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 1j,
    'yrebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': r"$v_{x}$ [cm]",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$v_{y}$ [cm]",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': './plots/',
    'outName': f'signal_cut7_vx_vs_vy_m1_{m1}_delta_{delta}_ctau_{ctau}.png'
}

ptools.plot_signal_2D(sig_histo, m1, delta, ctau, plot_dict, style_2d_dict)
# Out:
# Saved: ./plots//signal_cut7_vx_vs_vy_m1_30_delta_0.1_ctau_100.png
